# %%
import pandas as pd
import pandas_datareader as pdr
import FinanceDataReader as fdr

# %% [markdown]
# Dubai / 동 / 선박운임료 / 석탄의 경우 Bloomberg Terminal 활용하여 확보
# 코로나 관련 데이터는 깃허브의 csv파일로 확보
# S&P Energy 가격은 Investing.com을 통해 csv파일로 확보하였다.
# 그 외의 데이터는 Pandas_datareader 와 FinanceDataReader를 통해 확보하였다.

# %%
### WTI유 가격 불러오기

df_WTI = pdr.DataReader('DCOILWTICO', 'fred', start='2000-01-01', end = '2021-10-21')

print('row count:', len(df_WTI))
df_WTI.tail(10)
# Out:
# row count: 5689
#             DCOILWTICO
# DATE
# 2021-10-08       79.55
# 2021-10-11       80.64
# 2021-10-12       80.75
# 2021-10-13       80.67
# 2021-10-14       81.43
# 2021-10-15       82.39
# 2021-10-18       82.62
# 2021-10-19       83.19
# 2021-10-20       84.40
# 2021-10-21       82.64

# %%
### Brent유 가격 불러오기

df_Brent = pdr.DataReader('DCOILBRENTEU', 'fred', start='2001-01-01', end = '2021-10-21')

print('row count:', len(df_Brent))
df_Brent.head(10)
# Out:
# row count: 5429
#             DCOILBRENTEU
# DATE
# 2001-01-01           NaN
# 2001-01-02         23.43
# 2001-01-03         23.44
# 2001-01-04         24.57
# 2001-01-05         24.77
# 2001-01-08         24.75
# 2001-01-09         24.13
# 2001-01-10         24.98
# 2001-01-11         25.60
# 2001-01-12         25.63

# %%
### Dubai유 가격 불러오기

df_Dubai = pd.read_excel("data/dubai_weekly.xlsx")

print('row count:', len(df_Dubai))
df_Dubai.Date = pd.to_datetime(df_Dubai.Date)
df_Dubai.set_index(df_Dubai.Date,drop = True, inplace = True)
df_Dubai.drop(['Date'],axis = 1, inplace = True)
df_Dubai
# Out:
# row count: 145
#             Price
# Date
# 2021-09-30  72.53
# 2021-09-03  71.46
# 2021-07-09  66.10
# 2021-07-02  62.95
# 2021-06-04  64.28
# ...           ...
# 2010-01-08  77.49
# 2010-01-01  72.95
# 2009-12-04  68.04
# 2009-10-09  71.39
# 2009-10-02  65.02
#
# [145 rows x 1 columns]

# %%
### 천연가스 가격 불러오기

df_gas = pd.read_excel("data/natural_gas_daily.xlsx")

print('row count:', len(df_gas))
df_gas.Date = pd.to_datetime(df_gas.Date)
df_gas.set_index(df_gas.Date, drop = True, inplace = True)
df_gas.drop(['Date'],axis = 1, inplace = True)
df_gas
# Out:
# row count: 3851
#             Price
# Date
# 2021-10-20  5.170
# 2021-10-19  5.088
# 2021-10-18  4.989
# 2021-10-15  5.410
# 2021-10-14  5.687
# ...           ...
# 2006-07-28  7.184
# 2006-07-27  7.042
# 2006-07-26  6.887
# 2006-07-25  6.409
# 2006-07-24  6.605
#
# [3851 rows x 1 columns]

# %%
### 금가격 불러오기

df_gold = pdr.DataReader('GOLDAMGBD228NLBM', 'fred', start='2000-01-01', end = '2021-10-21')

print('row count:', len(df_gold))
df_gold.tail(10)
# Out:
# row count: 5689
#             GOLDAMGBD228NLBM
# DATE
# 2021-10-08           1757.50
# 2021-10-11           1752.55
# 2021-10-12           1759.10
# 2021-10-13           1767.45
# 2021-10-14           1797.15
# 2021-10-15           1781.45
# 2021-10-18           1762.45
# 2021-10-19           1779.40
# 2021-10-20           1778.15
# 2021-10-21           1785.30

# %%
### 은가격 불러오기

df_silver = pdr.DataReader('SLVPRUSD', 'fred', start='2008-01-01', end = '2021-10-21')

print('row count:', len(df_silver))
df_silver
# Out:
# row count: 1059
#             SLVPRUSD
# DATE
# 2017-10-02    16.580
# 2017-10-03    16.610
# 2017-10-04    16.825
# 2017-10-05    16.660
# 2017-10-06    16.625
# ...              ...
# 2021-10-15    23.240
# 2021-10-18    23.220
# 2021-10-19    23.730
# 2021-10-20    23.955
# 2021-10-21    24.230
#
# [1059 rows x 1 columns]

# %%
### 동가격 불러오기

df_copper = pd.read_excel('data/copper_daily.xlsx')

print('row count:', len(df_copper))
df_copper.Date = pd.to_datetime(df_copper.Date)
df_copper.set_index(df_copper.Date,drop = True, inplace = True)
df_copper.drop(['Date'],axis = 1, inplace = True)
df_copper
# Out:
# row count: 3528
#               Price
# Date
# 2021-10-20  10185.5
# 2021-10-19  10149.5
# 2021-10-18  10196.0
# 2021-10-15  10281.0
# 2021-10-14   9984.0
# ...             ...
# 2008-02-07   7540.0
# 2008-02-06   7330.0
# 2008-02-05   7130.0
# 2008-02-04   7260.0
# 2008-02-01   7230.0
#
# [3528 rows x 1 columns]

# %%
#코로나 데이터
import pandas as pd
import numpy as np
df_covid19= pd.read_csv('data/owid-covid-data.csv')

print('row count:', len(df_covid19))
df_covid19
# Out:
# row count: 125732
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 125727      ZWE    Africa     Zimbabwe  2021-10-19     132405.0       37.0
# 125728      ZWE    Africa     Zimbabwe  2021-10-20     132437.0       32.0
# 125729      ZWE    Africa     Zimbabwe  2021-10-21     132540.0      103.0
# 125730      ZWE    Africa     Zimbabwe  2021-10-22     132588.0       48.0
# 125731      ZWE    Africa     Zimbabwe  2021-10-23     132588.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 125727              55.571        4659.0         1.0                2.000
# 125728              47.000        4659.0         0.0                1.571
# 125729              41.286        4662.0         3.0                1.000
# 125730              43.286        4663.0         1.0                1.143
# 125731              36.429        4663.0         0.0                0.857
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 125727  ...             1.6          30.7                  36.791
# 125728  ...             1.6          30.7                  36.791
# 125729  ...             1.6          30.7                  36.791
# 125730  ...             1.6          30.7                  36.791
# 125731  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 125727                         1.7            61.49                    0.571
# 125728                         1.7            61.49                    0.571
# 125729                         1.7            61.49                    0.571
# 125730                         1.7            61.49                    0.571
# 125731                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 125727                                   NaN                          NaN
# 125728                                   NaN                          NaN
# 125729                                   NaN                          NaN
# 125730                                   NaN                          NaN
# 125731                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 125727               NaN                                      NaN
# 125728               NaN                                      NaN
# 125729               NaN                                      NaN
# 125730               NaN                                      NaN
# 125731               NaN                                      NaN
#
# [125732 rows x 65 columns]

# %% [markdown]
# Variable	:  Description
#
# *   total_cases	: Total confirmed cases of COVID-19
# * total_vaccinations : Total number of COVID-19 vaccination doses administered (투여된 수)
# *   people_fully_vaccinated: Total number of people who received all doses prescribed by the vaccination protocol (예방 접종 프로토콜에 명시된 모든 용량을 접종받은 총 사람 수)

# %%
df_tcvx= df_covid19[['continent','location', 'date', 'total_cases', 'new_vaccinations', 'people_fully_vaccinated', 'new_cases']]
df_tcvx = df_tcvx.fillna(0)
df_tcvx.tail()
# Out:
#        continent  location        date  total_cases  new_vaccinations  \
# 125727    Africa  Zimbabwe  2021-10-19     132405.0           13759.0
# 125728    Africa  Zimbabwe  2021-10-20     132437.0           24020.0
# 125729    Africa  Zimbabwe  2021-10-21     132540.0           16516.0
# 125730    Africa  Zimbabwe  2021-10-22     132588.0               0.0
# 125731    Africa  Zimbabwe  2021-10-23     132588.0               0.0
#
#         people_fully_vaccinated  new_cases
# 125727                2509195.0       37.0
# 125728                2523407.0       32.0
# 125729                2532854.0      103.0
# 125730                      0.0       48.0
# 125731                      0.0        0.0

# %%
### 코로나 백신 접종자수 불러오기
c_data = df_tcvx.groupby(['date']).sum()
corona_data = c_data[['new_cases','new_vaccinations']]
corona_data.index = pd.to_datetime(corona_data.index)
corona_data
# Out:
#             new_cases  new_vaccinations
# date
# 2020-01-01        0.0               0.0
# 2020-01-02        0.0               0.0
# 2020-01-03        0.0               0.0
# 2020-01-04        0.0               0.0
# 2020-01-05        0.0               0.0
# ...               ...               ...
# 2021-10-19  1419351.0        79280514.0
# 2021-10-20  1506523.0        87751863.0
# 2021-10-21  1473414.0        65003904.0
# 2021-10-22  1569272.0        51138783.0
# 2021-10-23  1139204.0               0.0
#
# [662 rows x 2 columns]

# %% [markdown]
# 코로나 데이터의 경우 NA값은 관측되지 않은 것이라고 판단, 자체적으로 0값으로 치환하였다.

# %%
### 선박운임료 불러오기

df_bdiy = pd.read_excel('data/bdiy_daily_data.xlsx')
print('row count:', len(df_bdiy))
df_bdiy.Date = pd.to_datetime(df_bdiy.Date)
df_bdiy.set_index(df_bdiy.Date,drop = True, inplace = True)
df_bdiy.drop(['Date'],axis = 1, inplace = True)
df_bdiy
# Out:
# row count: 3451
#             Price
# Date
# 2021-10-20   4751
# 2021-10-19   4714
# 2021-10-18   4732
# 2021-10-15   4854
# 2021-10-14   5062
# ...           ...
# 2008-01-08   8730
# 2008-01-07   8732
# 2008-01-04   8702
# 2008-01-03   8756
# 2008-01-02   8891
#
# [3451 rows x 1 columns]

# %%
### 석탄가격 불러오기
df_coal = pd.read_excel('data/coal_index_daily.xlsx')

print('row count:', len(df_coal))
df_coal.Date = pd.to_datetime(df_coal.Date)
df_coal.set_index(df_coal.Date,drop = True, inplace = True)
df_coal.drop(['Date'],axis = 1, inplace = True)
df_coal
# Out:
# row count: 3390
#               Price
# Date
# 2020-12-18  1195.81
# 2020-12-17  1179.04
# 2020-12-16  1177.70
# 2020-12-15  1159.74
# 2020-12-14  1164.29
# ...             ...
# 2007-12-18  5240.59
# 2007-12-17  5216.20
# 2007-12-14  5371.14
# 2007-12-13  5450.96
# 2007-12-12  5514.90
#
# [3390 rows x 1 columns]

# %%
### 비트코인 불러오기

df = fdr.DataReader('BTC/USD', '2015-01-01', '2021-10-21')
df_bit = df['Close']
df_bit
# Out:
# Date
# 2015-01-01      314.9
# 2015-01-02      315.2
# 2015-01-03      287.1
# 2015-01-04      264.7
# 2015-01-05      274.8
#                ...
# 2021-10-17    61527.5
# 2021-10-18    62056.3
# 2021-10-19    64278.5
# 2021-10-20    65979.1
# 2021-10-21    62210.2
# Name: Close, Length: 2486, dtype: float64

# %%
### 달러인덱스 불러오기

df = fdr.DataReader('DX', '2008-01-01', '2021-10-21')
df_dollar = df['Close']
df_dollar
# Out:
# Date
# 2008-01-02    76.010
# 2008-01-03    75.920
# 2008-01-04    75.820
# 2008-01-07    76.200
# 2008-01-08    76.120
#                ...
# 2021-10-15    93.938
# 2021-10-18    93.945
# 2021-10-19    93.728
# 2021-10-20    93.535
# 2021-10-21    93.758
# Name: Close, Length: 3560, dtype: float64

# %%
### S&P지수 불러오기

df = fdr.DataReader('US500', '2008-01-01', '2021-10-21')
df_Snp = df['Close']
df_Snp
# Out:
# Date
# 2008-01-02    1447.16
# 2008-01-03    1447.16
# 2008-01-04    1411.63
# 2008-01-07    1416.18
# 2008-01-08    1390.19
#                ...
# 2021-10-15    4471.37
# 2021-10-18    4486.48
# 2021-10-19    4519.63
# 2021-10-20    4536.19
# 2021-10-21    4549.78
# Name: Close, Length: 3477, dtype: float64

# %%
### S&P Energy index 불러오기

df = pd.read_csv('data/S&PEnergy.csv')
df.Date = pd.to_datetime(df.Date)
df.set_index(df.Date,drop = True, inplace = True)
df.drop(['Date'],axis = 1, inplace = True)
# for idx, val in enumerate(df['Vol.']):
#     new = val[0:-1]
#     print(idx, new)
#     float(new)
df_energy = df[['Open','High','Low','Vol.','Price']]
df_energy
# Out:
#               Open    High     Low     Vol.   Price
# Date
# 2021-10-25  439.56  448.63  439.56  177.93M  445.91
# 2021-10-22  435.50  440.04  433.27  160.55M  439.56
# 2021-10-21  443.53  443.53  432.10  204.82M  435.50
# 2021-10-20  439.87  443.62  435.16  173.73M  443.53
# 2021-10-19  434.89  441.40  434.47  175.70M  439.87
# ...            ...     ...     ...      ...     ...
# 2007-10-03  579.86  579.86  570.66  151.00M  574.23
# 2007-10-02  587.30  587.30  573.45  164.89M  579.86
# 2007-10-01  579.47  587.65  578.33  156.07M  587.30
# 2007-09-28  582.05  587.63  576.68  147.43M  579.47
# 2007-09-27  576.89  583.47  576.89  146.26M  582.05
#
# [3549 rows x 5 columns]

# %% [markdown]
# # 데이터 합치기 및 확인(+EDA)

# %%
# 데이터 합본
data_list = (df_WTI, df_Brent,df_Dubai,df_gas,df_gold,df_silver,df_copper,df_bdiy,df_coal,corona_data,df_dollar,df_Snp,df_energy)
df_raw = pd.DataFrame()
for i in data_list:
    df_raw = pd.concat([df_raw, i], axis = 1)

df_raw.columns = ['WTI','Brent','Dubai','Gas','Gold','Silver','Copper','Bdiy','Coal','new_cases','vaccination','Bitcoin','Snp','Open','High','Low','Volume','Energy']
df_raw
# Out:
#               WTI  Brent  Dubai   Gas     Gold  Silver   Copper    Bdiy  Coal  \
# 2000-01-03    NaN    NaN    NaN   NaN      NaN     NaN      NaN     NaN   NaN
# 2000-01-04  25.56    NaN    NaN   NaN   282.05     NaN      NaN     NaN   NaN
# 2000-01-05  24.65    NaN    NaN   NaN   282.10     NaN      NaN     NaN   NaN
# 2000-01-06  24.79    NaN    NaN   NaN   280.35     NaN      NaN     NaN   NaN
# 2000-01-07  24.79    NaN    NaN   NaN   282.00     NaN      NaN     NaN   NaN
# ...           ...    ...    ...   ...      ...     ...      ...     ...   ...
# 2021-10-20  84.40  85.76    NaN  5.17  1778.15  23.955  10185.5  4751.0   NaN
# 2021-10-21  82.64  84.58    NaN   NaN  1785.30  24.230      NaN     NaN   NaN
# 2021-10-22    NaN    NaN    NaN   NaN      NaN     NaN      NaN     NaN   NaN
# 2021-10-23    NaN    NaN    NaN   NaN      NaN     NaN      NaN     NaN   NaN
# 2021-10-25    NaN    NaN    NaN   NaN      NaN     NaN      NaN     NaN   NaN
#
#             new_cases  vaccination  Bitcoin      Snp    Open    High     Low  \
# 2000-01-03        NaN          NaN      NaN      NaN     NaN     NaN     NaN
# 2000-01-04        NaN          NaN      NaN      NaN     NaN     NaN     NaN
# 2000-01-05        NaN          NaN      NaN      NaN     NaN     NaN     NaN
# 2000-01-06        NaN          NaN      NaN      NaN     NaN     NaN     NaN
# 2000-01-07        NaN          NaN      NaN      NaN     NaN     NaN     NaN
# ...               ...          ...      ...      ...     ...     ...     ...
# 2021-10-20  1506523.0   87751863.0   93.535  4536.19  439.87  443.62  435.16
# 2021-10-21  1473414.0   65003904.0   93.758  4549.78  443.53  443.53  432.10
# 2021-10-22  1569272.0   51138783.0      NaN      NaN  435.50  440.04  433.27
# 2021-10-23  1139204.0          0.0      NaN      NaN     NaN     NaN     NaN
# 2021-10-25        NaN          NaN      NaN      NaN  439.56  448.63  439.56
#
#              Volume  Energy
# 2000-01-03      NaN     NaN
# 2000-01-04      NaN     NaN
# 2000-01-05      NaN     NaN
# 2000-01-06      NaN     NaN
# 2000-01-07      NaN     NaN
# ...             ...     ...
# 2021-10-20  173.73M  443.53
# 2021-10-21  204.82M  435.50
# 2021-10-22  160.55M  439.56
# 2021-10-23      NaN     NaN
# 2021-10-25  177.93M  445.91
#
# [5880 rows x 18 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5880 entries, 2000-01-03 to 2021-10-25
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   WTI          5474 non-null   float64
#  1   Brent        5287 non-null   float64
#  2   Dubai        145 non-null    float64
#  3   Gas          3843 non-null   float64
#  4   Gold         5509 non-null   float64
#  5   Silver       1021 non-null   float64
#  6   Copper       3468 non-null   float64
#  7   Bdiy         3451 non-null   float64
#  8   Coal         3342 non-null   float64
#  9   new_cases    662 non-null    float64
#  10  vaccination  662 non-null    float64
#  11  Bitcoin      3560 non-null   float64
#  12  Snp          3477 non-null   float64
#  13  Open         3549 non-null   float64
#  14  High         3549 non-null   float64
#  15  Low          3549 non-null   float64
#  16  Volume       3549 non-null   object
#  17  Energy       3549 non-null   float64
# dtypes: float64(17), object(1)
# memory usage: 872.8+ KB

# %% [markdown]
# #### 은의 경우 1000여개 / 두바이의 경우 월 가격 데이터를 확보하였다. 따라서 이 두개의 데이터는 탈락시키고 활용할 계획이다
# (석탄은 2020년까지이므로 잠시 탈락)

# %%
df_raw.describe()
# Out:
#                WTI        Brent       Dubai          Gas         Gold  \
# count  5474.000000  5287.000000  145.000000  3843.000000  5509.000000
# mean     61.004534    65.152296   73.751172     4.011943  1005.087666
# std      25.735368    28.862670   25.246233     1.975923   503.668797
# min     -36.980000     9.120000   22.650000     1.482000   256.700000
# 25%      40.452500    43.505000   54.390000     2.734500   437.350000
# 50%      58.180000    61.890000   69.940000     3.467000  1160.950000
# 75%      79.705000    81.935000  102.230000     4.459500  1335.850000
# max     145.310000   143.950000  122.100000    13.577000  2061.500000
#
#             Silver        Copper          Bdiy         Coal     new_cases  \
# count  1021.000000   3468.000000   3451.000000  3342.000000  6.620000e+02
# mean     19.048991   6758.228590   1828.730223  2799.604324  1.160036e+06
# std       4.464614   1452.733206   1785.772142  1797.331883  7.756418e+05
# min      12.005000   2845.000000    290.000000   573.590000  0.000000e+00
# 25%      15.565000   5821.750000    868.500000  1486.387500  4.159292e+05
# 50%      17.070000   6739.500000   1262.000000  2079.615000  1.190258e+06
# 75%      23.835000   7680.000000   1960.000000  4326.652500  1.754110e+06
# max      29.585000  10460.000000  11793.000000  8019.460000  2.899671e+06
#
#         vaccination      Bitcoin          Snp         Open         High  \
# count  6.620000e+02  3560.000000  3477.000000  3549.000000  3549.000000
# mean   3.035822e+07    87.706397  2055.858361   491.983474   496.795238
# std    4.321973e+07     8.435555   879.318882   100.771609   100.230308
# min    0.000000e+00    71.304000   676.530000   179.940000   193.260000
# 25%    0.000000e+00    80.201000  1319.050000   426.790000   430.540000
# 50%    0.000000e+00    88.489000  1973.280000   501.470000   505.750000
# 75%    6.290904e+07    95.645750  2680.500000   560.730000   565.890000
# max    1.549071e+08   103.605000  4549.780000   736.840000   738.710000
#
#                Low       Energy
# count  3549.000000  3549.000000
# mean    486.862516   491.955638
# std     101.205875   100.759319
# min     172.450000   179.940000
# 25%     422.060000   426.790000
# 50%     496.650000   501.470000
# 75%     556.160000   560.660000
# max     734.510000   737.090000

# %%
#2008년 데이터 합본 ( 동 가격을 기준으로 2월 시작이다)
data_list = (df_WTI, df_Brent,df_gas,df_gold,df_copper,df_bdiy,df_dollar,df_Snp,df_energy)
df_2008 = pd.DataFrame()
for i in data_list:
    df_2008 = pd.concat([df_2008, i], axis = 1)

df_2008 = df_2008.dropna()
df_2008 = df_2008.reset_index()
df_2008.columns = ['Date','WTI','Brent','Gas','Gold','Copper','Bdiy','Dollar','Snp','Open','High','Low','Volume','Energy']
df_2008
# Out:
#            Date    WTI  Brent    Gas     Gold   Copper    Bdiy  Dollar  \
# 0    2008-02-01  89.03  91.41  7.740   933.00   7230.0  6134.0  75.565
# 1    2008-02-04  90.07  91.09  7.869   899.50   7260.0  6121.0  75.470
# 2    2008-02-05  88.32  89.60  7.942   889.75   7130.0  6032.0  76.285
# 3    2008-02-06  87.16  88.73  7.994   892.00   7330.0  6002.0  76.300
# 4    2008-02-07  88.07  88.55  8.102   908.25   7540.0  6135.0  77.120
# ...         ...    ...    ...    ...      ...      ...     ...     ...
# 3338 2021-10-14  81.43  83.86  5.687  1797.15   9984.0  5062.0  93.961
# 3339 2021-10-15  82.39  84.67  5.410  1781.45  10281.0  4854.0  93.938
# 3340 2021-10-18  82.62  84.13  4.989  1762.45  10196.0  4732.0  93.945
# 3341 2021-10-19  83.19  85.02  5.088  1779.40  10149.5  4714.0  93.728
# 3342 2021-10-20  84.40  85.76  5.170  1778.15  10185.5  4751.0  93.535
#
#           Snp    Open    High     Low   Volume  Energy
# 0     1395.42  537.15  544.62  534.29  238.36M  540.81
# 1     1380.82  540.81  544.41  535.15  188.02M  541.30
# 2     1336.64  541.29  541.29  521.00  243.54M  521.00
# 3     1326.45  520.99  527.14  511.26  243.06M  512.79
# 4     1336.91  512.10  523.59  507.85  234.50M  518.83
# ...       ...     ...     ...     ...      ...     ...
# 3338  4438.23  427.19  433.94  427.19  167.51M  432.43
# 3339  4471.37  432.43  438.73  432.43  173.94M  434.44
# 3340  4486.48  434.44  441.08  432.57  217.66M  434.89
# 3341  4519.63  434.89  441.40  434.47  175.70M  439.87
# 3342  4536.19  439.87  443.62  435.16  173.73M  443.53
#
# [3343 rows x 14 columns]

# %%
df_2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3343 entries, 0 to 3342
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3343 non-null   datetime64[ns]
#  1   WTI     3343 non-null   float64
#  2   Brent   3343 non-null   float64
#  3   Gas     3343 non-null   float64
#  4   Gold    3343 non-null   float64
#  5   Copper  3343 non-null   float64
#  6   Bdiy    3343 non-null   float64
#  7   Dollar  3343 non-null   float64
#  8   Snp     3343 non-null   float64
#  9   Open    3343 non-null   float64
#  10  High    3343 non-null   float64
#  11  Low     3343 non-null   float64
#  12  Volume  3343 non-null   object
#  13  Energy  3343 non-null   float64
# dtypes: datetime64[ns](1), float64(12), object(1)
# memory usage: 365.8+ KB

# %%
#2020년 데이터 합본
data_list = (df_WTI, df_Brent,df_gas,df_gold,df_copper,df_bdiy,corona_data,df_dollar,df_bit,df_Snp,df_energy)
df_2020 = pd.DataFrame()
for i in data_list:
    df_2020 = pd.concat([df_2020, i], axis = 1)
    
df_2020 = df_2020.dropna()
df_2020 = df_2020.reset_index()
df_2020.columns = ['Date','WTI','Brent','Gas','Gold','Copper','Bdiy','new_cases','vaccination','Dollar','Bitcoin','Snp','Open','High','Low','Volume','Energy']

# for idx, val in enumerate(df_2020['Volume']):
#     new = val[0:-1]
#     float(new)
df_2020
# Out:
#           Date    WTI  Brent    Gas     Gold   Copper    Bdiy  new_cases  \
# 0   2020-01-02  61.17  67.05  2.122  1520.55   6188.0   976.0        0.0
# 1   2020-01-03  63.00  69.08  2.130  1547.40   6129.5   907.0        0.0
# 2   2020-01-06  63.27  70.25  2.135  1576.85   6138.5   844.0        0.0
# 3   2020-01-07  62.70  68.74  2.162  1566.50   6149.0   791.0        0.0
# 4   2020-01-08  59.65  67.31  2.141  1582.85   6178.0   773.0        0.0
# ..         ...    ...    ...    ...      ...      ...     ...        ...
# 436 2021-10-14  81.43  83.86  5.687  1797.15   9984.0  5062.0  1407791.0
# 437 2021-10-15  82.39  84.67  5.410  1781.45  10281.0  4854.0  1458486.0
# 438 2021-10-18  82.62  84.13  4.989  1762.45  10196.0  4732.0  1339231.0
# 439 2021-10-19  83.19  85.02  5.088  1779.40  10149.5  4714.0  1419351.0
# 440 2021-10-20  84.40  85.76  5.170  1778.15  10185.5  4751.0  1506523.0
#
#      vaccination  Dollar  Bitcoin      Snp    Open    High     Low   Volume  \
# 0            0.0  96.525   6967.0  3257.85  456.46  460.93  456.46  133.61M
# 1            0.0  96.521   7343.1  3234.85  460.34  465.54  456.81  171.55M
# 2            0.0  96.350   7759.1  3246.28  458.77  464.81  458.77  195.33M
# 3            0.0  96.702   8155.7  3237.18  462.34  462.34  455.75  197.25M
# 4            0.0  96.996   8059.6  3253.05  461.39  461.39  452.84  187.23M
# ..           ...     ...      ...      ...     ...     ...     ...      ...
# 436   63331126.0  93.961  57345.8  4438.23  427.19  433.94  427.19  167.51M
# 437   68354252.0  93.938  61672.5  4471.37  432.43  438.73  432.43  173.94M
# 438   69279898.0  93.945  62056.3  4486.48  434.44  441.08  432.57  217.66M
# 439   79280514.0  93.728  64278.5  4519.63  434.89  441.40  434.47  175.70M
# 440   87751863.0  93.535  65979.1  4536.19  439.87  443.62  435.16  173.73M
#
#      Energy
# 0    460.34
# 1    458.77
# 2    462.34
# 3    461.39
# 4    453.36
# ..      ...
# 436  432.43
# 437  434.44
# 438  434.89
# 439  439.87
# 440  443.53
#
# [441 rows x 17 columns]

# %% [markdown]
# # 2008년 이후부터 계속 있는 데이터
# ## 기름 / 금속류 / bdiy / 석탄 / 달러 / SNP
#
#
# # 2020년 코로나 데이터를 포함하는 데이터
# ## + 코로나 / 비트코인

# %% [markdown]
# EDA 및 시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_hm=df_2008.drop(['Open','High', 'Low'],axis=1)
df_hm.head()
df_hm_corr = df_hm.corr()
df_hm_corr
# Out:
#              WTI     Brent       Gas      Gold    Copper      Bdiy    Dollar  \
# WTI     1.000000  0.971166  0.604269 -0.029669  0.657168  0.467595 -0.830272
# Brent   0.971166  1.000000  0.478414  0.101399  0.687422  0.335875 -0.801057
# Gas     0.604269  0.478414  1.000000 -0.466221  0.267487  0.839320 -0.604868
# Gold   -0.029669  0.101399 -0.466221  1.000000  0.497036 -0.302230  0.108119
# Copper  0.657168  0.687422  0.267487  0.497036  1.000000  0.336815 -0.534131
# Bdiy    0.467595  0.335875  0.839320 -0.302230  0.336815  1.000000 -0.457353
# Dollar -0.830272 -0.801057 -0.604868  0.108119 -0.534131 -0.457353  1.000000
# Snp    -0.440995 -0.418905 -0.392266  0.521617  0.092887 -0.146624  0.674689
# Energy  0.630012  0.639576  0.281012 -0.250568  0.222676  0.034603 -0.327604
#
#              Snp    Energy
# WTI    -0.440995  0.630012
# Brent  -0.418905  0.639576
# Gas    -0.392266  0.281012
# Gold    0.521617 -0.250568
# Copper  0.092887  0.222676
# Bdiy   -0.146624  0.034603
# Dollar  0.674689 -0.327604
# Snp     1.000000 -0.299881
# Energy -0.299881  1.000000

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df_hm_corr, annot=True)
plt.title('Stock correlation', fontsize=20)
plt.show()

# %%
X= df_hm.index
y1= df_hm.WTI
y2= df_hm.Brent
y3= df_hm.Gas
y4= df_hm.Gold
y5= df_hm.Copper
y6= df_hm.Bdiy
y7= df_hm.Dollar
y8= df_hm.Snp
#y9= df_hm.Volume
y10= df_hm.Energy

# %%
plt.figure(figsize=(20,7))
plt.plot(X, y1, label = 'WTI')
plt.plot(X, y2, label = 'Brent')
plt.plot(X, y3, label = 'Gas')
plt.plot(X, y4, label = 'Gold')
plt.plot(X, y5, label = 'Copper')
plt.plot(X, y6, label = 'Bdiy')
plt.plot(X, y7, label = 'Dollar')
plt.plot(X, y8, label = 'SNP')
# plt.plot(X, y9, label = 'Volume')
plt.plot(X, y10, label = 'Energy')

plt.legend(loc='upper left')
plt.title('Stock Price')
plt.xlabel('Date')
plt.ylabel('Price')

plt.show()

# %%
#변동수치로 데이터 셋 만들기
#df_raw['Energy_shift'] = (df_raw.Energy - df_raw.Energy.shift(1)) / df_raw.Energy.shift(1) * 100
#df_raw.Energy_shift

# %%
X = df_2008.iloc[:,1:12]  # volume 값의 경우 2019년 이후로 작성되지 않아 여기선 미반영 하겠다
y = df_2008['Energy']

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y,X)

res = model.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 Energy   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          7.944e+06
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        09:23:09   Log-Likelihood:                         -8515.7
# No. Observations:                3343   AIC:                                  1.705e+04
# Df Residuals:                    3332   BIC:                                  1.712e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# WTI            0.0237      0.013      1.762      0.078      -0.003       0.050
# Brent         -0.0216      0.013     -1.717      0.086      -0.046       0.003
# Gas           -0.0142      0.076     -0.187      0.851      -0.163       0.135
# Gold        9.272e-06      0.000      0.021      0.983      -0.001       0.001
# Copper         0.0001   7.51e-05      1.384      0.167   -4.33e-05       0.000
# Bdiy       -9.147e-05   7.17e-05     -1.276      0.202      -0.000     4.9e-05
# Dollar         0.0031      0.007      0.462      0.644      -0.010       0.016
# Snp           -0.0002      0.000     -2.359      0.018      -0.000    -4.1e-05
# Open          -0.5800      0.011    -50.564      0.000      -0.602      -0.557
# High           0.8019      0.013     64.009      0.000       0.777       0.826
# Low            0.7776      0.011     73.512      0.000       0.757       0.798
# ==============================================================================
# Omnibus:                      322.300   Durbin-Watson:                   2.272
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2355.471
# Skew:                           0.075   Prob(JB):                         0.00
# Kurtosis:                       7.109   Cond. No.                     1.09e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.09e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Train/Test Split

# %%
X = np.array(X)
y = np.array(y)

# %%
X
# Out:
# array([[ 89.03 ,  91.41 ,   7.74 , ..., 537.15 , 544.62 , 534.29 ],
#        [ 90.07 ,  91.09 ,   7.869, ..., 540.81 , 544.41 , 535.15 ],
#        [ 88.32 ,  89.6  ,   7.942, ..., 541.29 , 541.29 , 521.   ],
#        ...,
#        [ 82.62 ,  84.13 ,   4.989, ..., 434.44 , 441.08 , 432.57 ],
#        [ 83.19 ,  85.02 ,   5.088, ..., 434.89 , 441.4  , 434.47 ],
#        [ 84.4  ,  85.76 ,   5.17 , ..., 439.87 , 443.62 , 435.16 ]])

# %%
from sklearn.model_selection import TimeSeriesSplit

ts_cv = TimeSeriesSplit(
    n_splits=3,
    gap=0,
    max_train_size=3400,
    test_size=500,
)
all_splits = list(ts_cv.split(X, y))
train_0, test_0 = all_splits[0]
train_1, test_1 = all_splits[1]
train_2, test_2 = all_splits[2]

# %%
X[test_1].shape
# Out:
# (500, 11)

# %%
y[train_1].shape
# Out:
# (2343,)

# %%
# 시각화
from sklearn.model_selection import TimeSeriesSplit
from matplotlib.patches import Patch
import matplotlib.pyplot as plt

cmap_data = plt.cm.Paired 
cmap_cv = plt.cm.coolwarm 
plt.style.use('fivethirtyeight')

def plot_cv_indices(cv, X, n_splits, lw=10): 
  fig, ax = plt.subplots() 
  """Create a sample plot for indices of a cross-validation object.""" 
  
  # Generate the training/testing visualizations for each CV split 
  for ii, (tr, tt) in enumerate(cv.split(X=X)): 
    # Fill in indices with the training/test groups 
    indices = np.array([np.nan] * len(X)) 
    indices[tt] = 1 
    indices[tr] = 0 
    
    # Visualize the results 
    ax.scatter(range(len(indices)), [ii + .5] * len(indices),
               c=indices, marker='_', lw=lw, cmap=cmap_cv, 
               vmin=-.2, vmax=1.2) 
    # Formatting 
    yticklabels = list(range(n_splits)) 
    ax.set(yticks=np.arange(n_splits) + .5, yticklabels=yticklabels, 
           xlabel='Sample index', ylabel="CV iteration", 
           ylim=[n_splits+0.1, -.1], xlim=[0, len(X)]) 
    ax.set_title('{}'.format(type(cv).__name__), fontsize=15) 
    
    ax.legend([Patch(color=cmap_cv(.8)), Patch(color=cmap_cv(.02))], 
              ['Testing set', 'Training set'], loc=(1.02, .8))

# %%
n_split= 3
tscv= TimeSeriesSplit(n_splits=n_split)
plot_cv_indices(tscv, X, n_splits=n_split)

# %% [markdown]
# LSTM

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(X)
trainX = scaler.transform(X)
y = np.reshape(y ,(-1,1)) # 스케일러에 들어가려면 reshape이 필요함
scaler = scaler.fit(y)
trainy = scaler.transform(y)

# %%
def buildDataSet(X,y, seqLength):
    xdata= []
    ydata = []
    for i in range(0 , len(X)- seqLength):
        tx = X[i:i+seqLength]
        ty = y[i+seqLength]
        xdata.append(tx)
        ydata.append(ty)
    
    return np.array(xdata),np.array(ydata)

x_train, y_train = buildDataSet(trainX,trainy, 13)

# %%
x_train.shape
# Out:
# (3330, 13, 11)

# %%
x_train[train_1].shape
# Out:
# (2343, 13, 11)

# %% [markdown]
# 3개의 train 구분에 대하여 각각의 모델 적용 하는 함수를 작성해야 한다.

# %%
from tensorflow.keras.layers import SimpleRNN , LSTM , GRU , Dense
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(LSTM(16, 
               input_shape=(x_train.shape[1],x_train.shape[2]), 
               activation='tanh', 
               return_sequences=True)
          )
model.add(LSTM(16, activation = 'tanh'))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 13, 16)            1792
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 3,921
# Trainable params: 3,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse' , optimizer='adam' )

# %%
#early stop 추가 필요 / 모델 저장 코드 필요

# %%
hist = model.fit(x_train , y_train ,epochs=100, batch_size = 1000)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 14ms/step - loss: 0.5880
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3331
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1698
# Epoch 4/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0764
# Epoch 5/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0347
# Epoch 6/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0293
# Epoch 7/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0350
# Epoch 8/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0322
# Epoch 9/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0234
# Epoch 10/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0167
# Epoch 11/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0143
# Epoch 12/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0136
# Epoch 13/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0127
# Epoch 14/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0110
# Epoch 15/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0096
# Epoch 16/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0089
# Epoch 17/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0087
# Epoch 18/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0083
# Epoch 19/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0079
# Epoch 20/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0075
# Epoch 21/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0073
# Epoch 22/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0070
# Epoch 23/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0067
# Epoch 24/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0064
# Epoch 25/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0062
# Epoch 26/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0060
# Epoch 27/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0057
# Epoch 28/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0055
# Epoch 29/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0053
# Epoch 30/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0051
# Epoch 31/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0049
# Epoch 32/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0047
# Epoch 33/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0045
# Epoch 34/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0044
# Epoch 35/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0042
# Epoch 36/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0040
# Epoch 37/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0039
# Epoch 38/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0037
# Epoch 39/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 40/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0034
# Epoch 41/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0033
# Epoch 42/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 43/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0030
# Epoch 44/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 45/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 46/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 47/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 48/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0024
# Epoch 49/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0023
# Epoch 50/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 51/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 52/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021
# Epoch 53/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020
# Epoch 54/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0019
# Epoch 55/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 56/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 57/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 58/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 59/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0016
# Epoch 60/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0016
# Epoch 61/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0015
# Epoch 62/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0015
# Epoch 63/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0015
# Epoch 64/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 65/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 66/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 67/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 68/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 69/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 70/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 71/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 72/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 73/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 74/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 75/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 76/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 77/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 78/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 79/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 80/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 81/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 82/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 83/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 84/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 85/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 86/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 87/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 88/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 89/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 90/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 91/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 92/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 93/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 94/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 95/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 96/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 97/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 98/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 99/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 100/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0011

# %% [markdown]
# # S&P500 Energy 섹터 소속 5개 회사

# %%
### ExxonMobil 불러오기

df_XOM = fdr.DataReader('XOM', '2008-01-01', '2021-10-21')
df_XOM
# Out:
#             Close   Open   High    Low      Volume  Change
# Date
# 2008-01-02  93.51  94.15  94.55  92.78  23350000.0 -0.0019
# 2008-01-03  93.83  93.86  94.74  93.51  19170000.0  0.0034
# 2008-01-04  92.08  93.24  94.36  91.88  24730000.0 -0.0187
# 2008-01-07  91.22  92.50  93.15  90.25  28940000.0 -0.0093
# 2008-01-08  90.05  91.86  92.05  89.68  21760000.0 -0.0128
# ...           ...    ...    ...    ...         ...     ...
# 2021-10-15  62.59  62.73  63.07  62.44  16090000.0  0.0095
# 2021-10-18  62.56  63.09  63.14  62.27  18270000.0 -0.0005
# 2021-10-19  63.50  62.87  63.61  62.67  18930000.0  0.0150
# 2021-10-20  63.85  62.89  63.87  62.72  14260000.0  0.0055
# 2021-10-21  62.69  63.47  63.64  62.35  16480000.0 -0.0182
#
# [3477 rows x 6 columns]

# %%
### Chevron Corporation 불러오기

df_CVX = fdr.DataReader('CVX', '2008-01-01', '2021-10-21')
df_CVX
# Out:
#              Close    Open    High     Low      Volume  Change
# Date
# 2008-01-02   93.46   93.96   94.69   92.71   9060000.0  0.0014
# 2008-01-03   94.61   93.80   94.84   93.46  10480000.0  0.0123
# 2008-01-04   93.35   93.88   95.21   93.20  13100000.0 -0.0133
# 2008-01-07   92.13   93.74   93.74   91.15  12890000.0 -0.0131
# 2008-01-08   90.95   92.41   93.38   90.58  10990000.0 -0.0128
# ...            ...     ...     ...     ...         ...     ...
# 2021-10-15  109.61  109.77  110.03  109.43   9970000.0  0.0074
# 2021-10-18  109.56  110.22  110.41  108.96  10500000.0 -0.0005
# 2021-10-19  111.70  110.16  111.70  109.79  10360000.0  0.0195
# 2021-10-20  113.16  111.09  113.17  110.78  10740000.0  0.0131
# 2021-10-21  111.74  112.71  112.81  110.87   9330000.0 -0.0125
#
# [3477 rows x 6 columns]

# %%
### ConocoPhillips 불러오기

df_COP = fdr.DataReader('COP', '2008-01-01', '2021-10-21')
df_COP
# Out:
#             Close   Open   High    Low      Volume  Change
# Date
# 2008-01-02  67.00  67.66  68.39  66.22  11500000.0 -0.0046
# 2008-01-03  67.27  67.09  67.88  67.09   8590000.0  0.0040
# 2008-01-04  65.22  66.38  66.94  65.10  11120000.0 -0.0305
# 2008-01-07  64.33  65.75  65.93  63.87  13550000.0 -0.0136
# 2008-01-08  62.90  64.68  65.26  62.72  12370000.0 -0.0222
# ...           ...    ...    ...    ...         ...     ...
# 2021-10-15  74.14  74.63  74.93  74.13   6950000.0  0.0039
# 2021-10-18  74.50  74.77  75.75  74.13   9910000.0  0.0049
# 2021-10-19  75.32  74.84  75.85  74.38   6590000.0  0.0110
# 2021-10-20  76.02  74.72  76.10  74.54   5500000.0  0.0093
# 2021-10-21  74.59  75.65  75.65  74.11   5780000.0 -0.0188
#
# [3477 rows x 6 columns]

# %%
### Marathon Oil 불러오기

df_MRO = fdr.DataReader('MRO', '2008-01-01', '2021-10-21')
df_MRO
# Out:
#             Close   Open   High    Low      Volume  Change
# Date
# 2008-01-02  37.27  37.03  37.61  37.03   5690000.0  0.0087
# 2008-01-03  37.56  37.47  38.38  37.03   4800000.0  0.0078
# 2008-01-04  36.16  37.24  37.24  36.09   5970000.0 -0.0373
# 2008-01-07  35.79  36.11  36.58  35.42   7500000.0 -0.0102
# 2008-01-08  35.56  36.38  36.78  35.43   8520000.0 -0.0064
# ...           ...    ...    ...    ...         ...     ...
# 2021-10-15  16.18  16.42  16.53  16.16  12690000.0  0.0025
# 2021-10-18  16.43  16.48  16.84  16.24  25240000.0  0.0155
# 2021-10-19  16.39  16.46  16.62  16.27  18510000.0 -0.0024
# 2021-10-20  16.49  16.23  16.57  16.07  13130000.0  0.0061
# 2021-10-21  16.18  16.39  16.50  16.07  15010000.0 -0.0188
#
# [3477 rows x 6 columns]

# %%
### Kinder Morgan 불러오기

df_KMI = fdr.DataReader('KMI', '2008-01-01', '2021-10-21')
df_KMI
# Out:
#             Close   Open   High    Low      Volume  Change
# Date
# 2011-02-14  30.70  31.05  31.30  30.70   6280000.0 -0.0113
# 2011-02-15  30.94  30.90  31.15  30.73   4340000.0  0.0078
# 2011-02-16  30.72  31.05  31.44  30.66   4630000.0 -0.0071
# 2011-02-17  30.55  30.68  31.09  30.51   3290000.0 -0.0055
# 2011-02-18  31.37  30.65  31.39  30.40   6940000.0  0.0268
# ...           ...    ...    ...    ...         ...     ...
# 2021-10-15  18.46  18.44  18.61  18.39  12250000.0  0.0044
# 2021-10-18  18.47  18.56  18.76  18.35  15530000.0  0.0005
# 2021-10-19  18.45  18.56  18.61  18.34  10010000.0 -0.0011
# 2021-10-20  18.65  18.36  18.68  18.26  12190000.0  0.0108
# 2021-10-21  17.53  18.27  18.35  17.31  38490000.0 -0.0601
#
# [2691 rows x 6 columns]

# %%
#Evaluation
def evaluate(model, X, y, cv):
    cv_results = cross_validate(
        model,
        X,
        y,
        cv=cv,
        scoring=["neg_mean_absolute_error", "neg_root_mean_squared_error"],
    )
    mae = -cv_results["test_neg_mean_absolute_error"]
    rmse = -cv_results["test_neg_root_mean_squared_error"]
    print(
        f"Mean Absolute Error:     {mae.mean():.3f} +/- {mae.std():.3f}\n"
        f"Root Mean Squared Error: {rmse.mean():.3f} +/- {rmse.std():.3f}"
    )


evaluate(gbrt_pipeline, X, y, cv=ts_cv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-e5020bfbdf21> in <module>
#      16
#      17
# ---> 18 evaluate(gbrt_pipeline, X, y, cv=ts_cv)
#
# NameError: name 'gbrt_pipeline' is not defined

# %%
test_df_2008 = df_2008
test_df_2008
# Out:
#            Date    WTI  Brent    Gas     Gold   Copper    Bdiy  Dollar  \
# 0    2008-02-01  89.03  91.41  7.740   933.00   7230.0  6134.0  75.565
# 1    2008-02-04  90.07  91.09  7.869   899.50   7260.0  6121.0  75.470
# 2    2008-02-05  88.32  89.60  7.942   889.75   7130.0  6032.0  76.285
# 3    2008-02-06  87.16  88.73  7.994   892.00   7330.0  6002.0  76.300
# 4    2008-02-07  88.07  88.55  8.102   908.25   7540.0  6135.0  77.120
# ...         ...    ...    ...    ...      ...      ...     ...     ...
# 3338 2021-10-14  81.43  83.86  5.687  1797.15   9984.0  5062.0  93.961
# 3339 2021-10-15  82.39  84.67  5.410  1781.45  10281.0  4854.0  93.938
# 3340 2021-10-18  82.62  84.13  4.989  1762.45  10196.0  4732.0  93.945
# 3341 2021-10-19  83.19  85.02  5.088  1779.40  10149.5  4714.0  93.728
# 3342 2021-10-20  84.40  85.76  5.170  1778.15  10185.5  4751.0  93.535
#
#           Snp    Open    High     Low   Volume  Energy
# 0     1395.42  537.15  544.62  534.29  238.36M  540.81
# 1     1380.82  540.81  544.41  535.15  188.02M  541.30
# 2     1336.64  541.29  541.29  521.00  243.54M  521.00
# 3     1326.45  520.99  527.14  511.26  243.06M  512.79
# 4     1336.91  512.10  523.59  507.85  234.50M  518.83
# ...       ...     ...     ...     ...      ...     ...
# 3338  4438.23  427.19  433.94  427.19  167.51M  432.43
# 3339  4471.37  432.43  438.73  432.43  173.94M  434.44
# 3340  4486.48  434.44  441.08  432.57  217.66M  434.89
# 3341  4519.63  434.89  441.40  434.47  175.70M  439.87
# 3342  4536.19  439.87  443.62  435.16  173.73M  443.53
#
# [3343 rows x 14 columns]

# %% [markdown]
# ## 파마프렌치 모델 3요소// 일별

# %%
import pandas_datareader.data as web
import pandas_datareader.famafrench as ff
import statsmodels.api as smf

# %%
test_ff = ff.get_available_datasets( )

# %%
print( 'No. of datasets:{0}'.format( len( test_ff ) ) )
# Out:
# No. of datasets:297

# %%
print( test_ff )
# Out:
# ['F-F_Research_Data_Factors', 'F-F_Research_Data_Factors_weekly', 'F-F_Research_Data_Factors_daily', 'F-F_Research_Data_5_Factors_2x3', 'F-F_Research_Data_5_Factors_2x3_daily', 'Portfolios_Formed_on_ME', 'Portfolios_Formed_on_ME_Wout_Div', 'Portfolios_Formed_on_ME_Daily', 'Portfolios_Formed_on_BE-ME', 'Portfolios_Formed_on_BE-ME_Wout_Div', 'Portfolios_Formed_on_BE-ME_Daily', 'Portfolios_Formed_on_OP', 'Portfolios_Formed_on_OP_Wout_Div', 'Portfolios_Formed_on_OP_Daily', 'Portfolios_Formed_on_INV', 'Portfolios_Formed_on_INV_Wout_Div', 'Portfolios_Formed_on_INV_Daily', '6_Portfolios_2x3', '6_Portfolios_2x3_Wout_Div', '6_Portfolios_2x3_weekly', '6_Portfolios_2x3_daily', '25_Portfolios_5x5', '25_Portfolios_5x5_Wout_Div', '25_Portfolios_5x5_Daily', '100_Portfolios_10x10', '100_Portfolios_10x10_Wout_Div', '100_Portfolios_10x10_Daily', '6_Portfolios_ME_OP_2x3', '6_Portfolios_ME_OP_2x3_Wout_Div', '6_Portfolios_ME_OP_2x3_daily', '25_Portfolios_ME_OP_5x5', '25_Portfolios_ME_OP_5x5_Wout_Div', '25_Portfolios_ME_OP_5x5_daily', '100_Portfolios_ME_OP_10x10', '100_Portfolios_10x10_ME_OP_Wout_Div', '100_Portfolios_ME_OP_10x10_daily', '6_Portfolios_ME_INV_2x3', '6_Portfolios_ME_INV_2x3_Wout_Div', '6_Portfolios_ME_INV_2x3_daily', '25_Portfolios_ME_INV_5x5', '25_Portfolios_ME_INV_5x5_Wout_Div', '25_Portfolios_ME_INV_5x5_daily', '100_Portfolios_ME_INV_10x10', '100_Portfolios_10x10_ME_INV_Wout_Div', '100_Portfolios_ME_INV_10x10_daily', '25_Portfolios_BEME_OP_5x5', '25_Portfolios_BEME_OP_5x5_Wout_Div', '25_Portfolios_BEME_OP_5x5_daily', '25_Portfolios_BEME_INV_5x5', '25_Portfolios_BEME_INV_5x5_Wout_Div', '25_Portfolios_BEME_INV_5x5_daily', '25_Portfolios_OP_INV_5x5', '25_Portfolios_OP_INV_5x5_Wout_Div', '25_Portfolios_OP_INV_5x5_daily', '32_Portfolios_ME_BEME_OP_2x4x4', '32_Portfolios_ME_BEME_OP_2x4x4_Wout_Div', '32_Portfolios_ME_BEME_INV_2x4x4', '32_Portfolios_ME_BEME_INV_2x4x4_Wout_Div', '32_Portfolios_ME_OP_INV_2x4x4', '32_Portfolios_ME_OP_INV_2x4x4_Wout_Div', 'Portfolios_Formed_on_E-P', 'Portfolios_Formed_on_E-P_Wout_Div', 'Portfolios_Formed_on_CF-P', 'Portfolios_Formed_on_CF-P_Wout_Div', 'Portfolios_Formed_on_D-P', 'Portfolios_Formed_on_D-P_Wout_Div', '6_Portfolios_ME_EP_2x3', '6_Portfolios_ME_EP_2x3_Wout_Div', '6_Portfolios_ME_CFP_2x3', '6_Portfolios_ME_CFP_2x3_Wout_Div', '6_Portfolios_ME_DP_2x3', '6_Portfolios_ME_DP_2x3_Wout_Div', 'F-F_Momentum_Factor', 'F-F_Momentum_Factor_daily', '6_Portfolios_ME_Prior_12_2', '6_Portfolios_ME_Prior_12_2_Daily', '25_Portfolios_ME_Prior_12_2', '25_Portfolios_ME_Prior_12_2_Daily', '10_Portfolios_Prior_12_2', '10_Portfolios_Prior_12_2_Daily', 'F-F_ST_Reversal_Factor', 'F-F_ST_Reversal_Factor_daily', '6_Portfolios_ME_Prior_1_0', '6_Portfolios_ME_Prior_1_0_Daily', '25_Portfolios_ME_Prior_1_0', '25_Portfolios_ME_Prior_1_0_Daily', '10_Portfolios_Prior_1_0', '10_Portfolios_Prior_1_0_Daily', 'F-F_LT_Reversal_Factor', 'F-F_LT_Reversal_Factor_daily', '6_Portfolios_ME_Prior_60_13', '6_Portfolios_ME_Prior_60_13_Daily', '25_Portfolios_ME_Prior_60_13', '25_Portfolios_ME_Prior_60_13_Daily', '10_Portfolios_Prior_60_13', '10_Portfolios_Prior_60_13_Daily', 'Portfolios_Formed_on_AC', '25_Portfolios_ME_AC_5x5', 'Portfolios_Formed_on_BETA', '25_Portfolios_ME_BETA_5x5', 'Portfolios_Formed_on_NI', '25_Portfolios_ME_NI_5x5', 'Portfolios_Formed_on_VAR', '25_Portfolios_ME_VAR_5x5', 'Portfolios_Formed_on_RESVAR', '25_Portfolios_ME_RESVAR_5x5', '5_Industry_Portfolios', '5_Industry_Portfolios_Wout_Div', '5_Industry_Portfolios_daily', '10_Industry_Portfolios', '10_Industry_Portfolios_Wout_Div', '10_Industry_Portfolios_daily', '12_Industry_Portfolios', '12_Industry_Portfolios_Wout_Div', '12_Industry_Portfolios_daily', '17_Industry_Portfolios', '17_Industry_Portfolios_Wout_Div', '17_Industry_Portfolios_daily', '30_Industry_Portfolios', '30_Industry_Portfolios_Wout_Div', '30_Industry_Portfolios_daily', '38_Industry_Portfolios', '38_Industry_Portfolios_Wout_Div', '38_Industry_Portfolios_daily', '48_Industry_Portfolios', '48_Industry_Portfolios ...

# %%
df_industry = [ test_ff for test_ff in test_ff if 'daily' in test_ff]
print(df_industry)
# Out:
# ['F-F_Research_Data_Factors_daily', 'F-F_Research_Data_5_Factors_2x3_daily', '6_Portfolios_2x3_daily', '6_Portfolios_ME_OP_2x3_daily', '25_Portfolios_ME_OP_5x5_daily', '100_Portfolios_ME_OP_10x10_daily', '6_Portfolios_ME_INV_2x3_daily', '25_Portfolios_ME_INV_5x5_daily', '100_Portfolios_ME_INV_10x10_daily', '25_Portfolios_BEME_OP_5x5_daily', '25_Portfolios_BEME_INV_5x5_daily', '25_Portfolios_OP_INV_5x5_daily', 'F-F_Momentum_Factor_daily', 'F-F_ST_Reversal_Factor_daily', 'F-F_LT_Reversal_Factor_daily', '5_Industry_Portfolios_daily', '10_Industry_Portfolios_daily', '12_Industry_Portfolios_daily', '17_Industry_Portfolios_daily', '30_Industry_Portfolios_daily', '38_Industry_Portfolios_daily', '48_Industry_Portfolios_daily', '49_Industry_Portfolios_daily', 'Developed_6_Portfolios_ME_BE-ME_daily', 'Developed_ex_US_6_Portfolios_ME_BE-ME_daily', 'Europe_6_Portfolios_ME_BE-ME_daily', 'Japan_6_Portfolios_ME_BE-ME_daily', 'Asia_Pacific_ex_Japan_6_Portfolios_ME_BE-ME_daily', 'North_America_6_Portfolios_ME_BE-ME_daily', 'Developed_25_Portfolios_ME_BE-ME_daily', 'Developed_ex_US_25_Portfolios_ME_BE-ME_daily', 'Europe_25_Portfolios_ME_BE-ME_daily', 'Japan_25_Portfolios_ME_BE-ME_daily', 'Asia_Pacific_ex_Japan_25_Portfolios_ME_BE-ME_daily', 'North_America_25_Portfolios_ME_BE-ME_daily', 'Developed_6_Portfolios_ME_Prior_250_20_daily', 'Developed_ex_US_6_Portfolios_ME_Prior_250_20_daily', 'Europe_6_Portfolios_ME_Prior_250_20_daily', 'Japan_6_Portfolios_ME_Prior_250_20_daily', 'Asia_Pacific_ex_Japan_6_Portfolios_ME_Prior_250_20_daily', 'North_America_6_Portfolios_ME_Prior_250_20_daily', 'Developed_25_Portfolios_ME_Prior_250_20_daily', 'Developed_ex_US_25_Portfolios_ME_Prior_250_20_daily', 'Europe_25_Portfolios_ME_Prior_250_20_daily', 'Japan_25_Portfolios_ME_Prior_250_20_daily', 'Asia_Pacific_ex_Japan_25_Portfolios_ME_Prior_250_20_daily', 'North_America_25_Portfolios_ME_Prior_250_20_daily']

# %%
df_KMI_2 = df_KMI['Close']
df_KMI_2
# Out:
# Date
# 2011-02-14    30.70
# 2011-02-15    30.94
# 2011-02-16    30.72
# 2011-02-17    30.55
# 2011-02-18    31.37
#               ...
# 2021-10-15    18.46
# 2021-10-18    18.47
# 2021-10-19    18.45
# 2021-10-20    18.65
# 2021-10-21    17.53
# Name: Close, Length: 2691, dtype: float64

# %%
df_4_factor = df_industry[0]

# %%
ds_factors_1 = web.DataReader(df_4_factor,'famafrench', start='2008-01-01', end='2021-10-21')
print(ds_factors_1)
# Out:
# {0:             Mkt-RF   SMB   HML    RF
# Date
# 2008-01-02   -1.46 -0.08 -0.12  0.01
# 2008-01-03   -0.14 -1.02 -0.42  0.01
# 2008-01-04   -2.56 -0.48  0.05  0.01
# 2008-01-07    0.16  0.14  0.20  0.01
# 2008-01-08   -1.81 -0.43 -0.93  0.01
# ...            ...   ...   ...   ...
# 2021-09-24    0.08 -0.46  0.70  0.00
# 2021-09-27   -0.10  1.27  2.39  0.00
# 2021-09-28   -2.18 -0.42  1.75  0.00
# 2021-09-29    0.03 -0.29  0.80  0.00
# 2021-09-30   -1.02  0.30 -0.77  0.00
#
# [3462 rows x 4 columns], 'DESCR': 'F-F Research Data Factors daily\n-------------------------------\n\nThis file was created by CMPT_ME_BEME_RETS_DAILY using the 202109 CRSP database. The Tbill return is the simple daily rate that, over the number of trading days in the month, compounds to 1-month TBill rate from Ibbotson and Associates Inc. Copyright 2021 Kenneth R. French\n\n  0 : (3462 rows x 4 cols)'}

# %%
ds_factors_1[0].index = ds_factors_1[0].index.strftime('%Y-%m-%d')
ds_factors_1
# Out:
# {0:             Mkt-RF   SMB   HML    RF
#  Date
#  2008-01-02   -1.46 -0.08 -0.12  0.01
#  2008-01-03   -0.14 -1.02 -0.42  0.01
#  2008-01-04   -2.56 -0.48  0.05  0.01
#  2008-01-07    0.16  0.14  0.20  0.01
#  2008-01-08   -1.81 -0.43 -0.93  0.01
#  ...            ...   ...   ...   ...
#  2021-09-24    0.08 -0.46  0.70  0.00
#  2021-09-27   -0.10  1.27  2.39  0.00
#  2021-09-28   -2.18 -0.42  1.75  0.00
#  2021-09-29    0.03 -0.29  0.80  0.00
#  2021-09-30   -1.02  0.30 -0.77  0.00
#
#  [3462 rows x 4 columns],
#  'DESCR': 'F-F Research Data Factors daily\n-------------------------------\n\nThis file was created by CMPT_ME_BEME_RETS_DAILY using the 202109 CRSP database. The Tbill return is the simple daily rate that, over the number of trading days in the month, compounds to 1-month TBill rate from Ibbotson and Associates Inc. Copyright 2021 Kenneth R. French\n\n  0 : (3462 rows x 4 cols)'}

# %%
ds_4_factors = ds_factors_1[0]

# %%
ret_data_1 = df_KMI_2.pct_change()[1:]
ret_data_1
# Out:
# Date
# 2011-02-15    0.007818
# 2011-02-16   -0.007111
# 2011-02-17   -0.005534
# 2011-02-18    0.026841
# 2011-02-22   -0.020720
#                 ...
# 2021-10-15    0.004353
# 2021-10-18    0.000542
# 2021-10-19   -0.001083
# 2021-10-20    0.010840
# 2021-10-21   -0.060054
# Name: Close, Length: 2690, dtype: float64

# %%
ret_data_1 = pd.DataFrame(ret_data_1)

# %%
ret_data_1.columns = ['portfolio']
ret_data_1
# Out:
#             portfolio
# Date
# 2011-02-15   0.007818
# 2011-02-16  -0.007111
# 2011-02-17  -0.005534
# 2011-02-18   0.026841
# 2011-02-22  -0.020720
# ...               ...
# 2021-10-15   0.004353
# 2021-10-18   0.000542
# 2021-10-19  -0.001083
# 2021-10-20   0.010840
# 2021-10-21  -0.060054
#
# [2690 rows x 1 columns]

# %%
regress_data_1=ret_data_1.merge(ds_4_factors, how = 'inner', left_index = True, right_index = True)

# %%
regress_data_1.rename(columns={"Mkt-RF" : "mkt_excess"}, inplace=True)

# %%
regress_data_1['port_excess'] = regress_data_1['portfolio'] - regress_data_1['RF']

# %%
model_1 = smf.formula.ols(formula = "port_excess ~ mkt_excess + SMB + HML", data = regress_data_1).fit( )

# %%
print(model_1.params)
print(model_1.summary())
# Out:
# Intercept    -0.002462
# mkt_excess    0.009103
# SMB           0.001938
# HML           0.006395
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_excess   R-squared:                       0.368
# Model:                            OLS   Adj. R-squared:                  0.367
# Method:                 Least Squares   F-statistic:                     518.6
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):          1.58e-265
# Time:                        16:43:08   Log-Likelihood:                 7320.2
# No. Observations:                2675   AIC:                        -1.463e+04
# Df Residuals:                    2671   BIC:                        -1.461e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0025      0.000     -8.104      0.000      -0.003      -0.002
# mkt_excess     0.0091      0.000     32.170      0.000       0.009       0.010
# SMB            0.0019      0.001      3.655      0.000       0.001       0.003
# HML            0.0064      0.000     15.572      0.000       0.006       0.007
# ==============================================================================
# Omnibus:                      672.940   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18740.475
# Skew:                           0.569   Prob(JB):                         0.00
# Kurtosis:                      15.917   Cond. No.                         2.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
rf_1 = regress_data_1['RF'].mean()
market_premium_1 = regress_data_1['mkt_excess'].mean()
size_premium_1 = regress_data_1['SMB'].mean()
value_premium_1 = regress_data_1['HML'].mean()

expected_daily_return = rf + b1 * market_premium_1 + b2 * size_premium_1 + b3 * value_premium_1 
expected_yearly_return = expected_daily_return * 365
print("Expected yearly return: " + str(expected_yearly_return))
# Out:
# Expected yearly return: 16.936057715967365

# %% [markdown]
# ## 파마 프렌치모델 3요소 // 월별로 되어있음..

# %%
datasets = ff.get_available_datasets( )

# %%
df_3_factor = datasets[0]

# %%
ds_factors = web.DataReader(df_3_factor,'famafrench', start='2008-01-01', end='2020-12-31')
print(ds_factors)
# Out:
# {0:          Mkt-RF   SMB   HML    RF
# Date
# 2008-01   -6.36 -0.98  4.01  0.21
# 2008-02   -3.09 -0.41 -0.84  0.13
# 2008-03   -0.93  0.77  0.35  0.17
# 2008-04    4.60 -1.72 -1.09  0.18
# 2008-05    1.86  2.95 -1.53  0.18
# ...         ...   ...   ...   ...
# 2020-08    7.63 -0.26 -2.92  0.01
# 2020-09   -3.63  0.02 -2.62  0.01
# 2020-10   -2.10  4.41  4.16  0.01
# 2020-11   12.47  5.65  2.13  0.01
# 2020-12    4.63  4.82 -1.43  0.01
#
# [156 rows x 4 columns], 1:       Mkt-RF    SMB    HML    RF
# Date
# 2008  -38.34   2.46   0.84  1.60
# 2009   28.26   9.35  -9.42  0.10
# 2010   17.37  14.29  -5.10  0.12
# 2011    0.44  -5.79  -8.54  0.04
# 2012   16.27  -1.32   9.85  0.06
# 2013   35.20   7.63   2.65  0.02
# 2014   11.71  -7.81  -1.46  0.02
# 2015    0.08  -3.92  -9.54  0.02
# 2016   13.30   6.64  22.62  0.20
# 2017   21.51  -4.95 -13.48  0.80
# 2018   -6.93  -3.34  -9.80  1.81
# 2019   28.28  -6.06 -10.48  2.14
# 2020   23.67  12.77 -46.31  0.44, 'DESCR': 'F-F Research Data Factors\n-------------------------\n\nThis file was created by CMPT_ME_BEME_RETS using the 202109 CRSP database. The 1-month TBill return is from Ibbotson and Associates, Inc. Copyright 2021 Kenneth R. French\n\n  0 : (156 rows x 4 cols)\n  1 : Annual Factors: January-December (13 rows x 4 cols)'}

# %%
ds_factors[0].index = ds_factors[0].index.strftime('%Y-%m-%d')
ds_factors
# Out:
# {0:             Mkt-RF   SMB   HML    RF
#  Date
#  2008-01-31   -6.36 -0.98  4.01  0.21
#  2008-02-29   -3.09 -0.41 -0.84  0.13
#  2008-03-31   -0.93  0.77  0.35  0.17
#  2008-04-30    4.60 -1.72 -1.09  0.18
#  2008-05-31    1.86  2.95 -1.53  0.18
#  ...            ...   ...   ...   ...
#  2020-08-31    7.63 -0.26 -2.92  0.01
#  2020-09-30   -3.63  0.02 -2.62  0.01
#  2020-10-31   -2.10  4.41  4.16  0.01
#  2020-11-30   12.47  5.65  2.13  0.01
#  2020-12-31    4.63  4.82 -1.43  0.01
#
#  [156 rows x 4 columns],
#  1:       Mkt-RF    SMB    HML    RF
#  Date
#  2008  -38.34   2.46   0.84  1.60
#  2009   28.26   9.35  -9.42  0.10
#  2010   17.37  14.29  -5.10  0.12
#  2011    0.44  -5.79  -8.54  0.04
#  2012   16.27  -1.32   9.85  0.06
#  2013   35.20   7.63   2.65  0.02
#  2014   11.71  -7.81  -1.46  0.02
#  2015    0.08  -3.92  -9.54  0.02
#  2016   13.30   6.64  22.62  0.20
#  2017   21.51  -4.95 -13.48  0.80
#  2018   -6.93  -3.34  -9.80  1.81
#  2019   28.28  -6.06 -10.48  2.14
#  2020   23.67  12.77 -46.31  0.44,
#  'DESCR': 'F-F Research Data Factors\n-------------------------\n\nThis file was created by CMPT_ME_BEME_RETS using the 202109 CRSP database. The 1-month TBill return is from Ibbotson and Associates, Inc. Copyright 2021 Kenneth R. French\n\n  0 : (156 rows x 4 cols)\n  1 : Annual Factors: January-December (13 rows x 4 cols)'}

# %%
ds_3_factors = ds_factors[0]

# %%
df_KMI_1 = df_KMI['Close']
df_KMI_1
# Out:
# Date
# 2011-02-14    30.70
# 2011-02-15    30.94
# 2011-02-16    30.72
# 2011-02-17    30.55
# 2011-02-18    31.37
#               ...
# 2021-10-15    18.46
# 2021-10-18    18.47
# 2021-10-19    18.45
# 2021-10-20    18.65
# 2021-10-21    17.53
# Name: Close, Length: 2691, dtype: float64

# %%
# df_KMI_1.index = df_KMI_1.index.strftime('%Y-%m-%d')

# %%
ret_data = df_KMI_1.pct_change()[1:]
ret_data
# Out:
# Date
# 2011-02-15    0.007818
# 2011-02-16   -0.007111
# 2011-02-17   -0.005534
# 2011-02-18    0.026841
# 2011-02-22   -0.020720
#                 ...
# 2021-10-15    0.004353
# 2021-10-18    0.000542
# 2021-10-19   -0.001083
# 2021-10-20    0.010840
# 2021-10-21   -0.060054
# Name: Close, Length: 2690, dtype: float64

# %%
ret_data = pd.DataFrame(ret_data)

# %%
ret_data.columns = ['portfolio']
ret_data
# Out:
#             portfolio
# Date
# 2011-02-15   0.007818
# 2011-02-16  -0.007111
# 2011-02-17  -0.005534
# 2011-02-18   0.026841
# 2011-02-22  -0.020720
# ...               ...
# 2021-10-15   0.004353
# 2021-10-18   0.000542
# 2021-10-19  -0.001083
# 2021-10-20   0.010840
# 2021-10-21  -0.060054
#
# [2690 rows x 1 columns]

# %%
regress_data=ret_data.merge(ds_3_factors, how = 'inner', left_index = True, right_index = True)

# %%
regress_data.rename(columns={"Mkt-RF" : "mkt_excess"}, inplace=True)

# %%
regress_data['port_excess'] = regress_data['portfolio'] - regress_data['RF']

# %%
model = smf.formula.ols(formula = "port_excess ~ mkt_excess + SMB + HML", data = regress_data).fit( )

# %%
print(model.params)
print(model.summary())
# Out:
# Intercept    -0.043111
# mkt_excess   -0.000830
# SMB           0.004265
# HML           0.001890
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_excess   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.7540
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):              0.523
# Time:                        16:20:21   Log-Likelihood:                 108.38
# No. Observations:                  85   AIC:                            -208.8
# Df Residuals:                      81   BIC:                            -199.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0431      0.008     -5.401      0.000      -0.059      -0.027
# mkt_excess    -0.0008      0.002     -0.416      0.678      -0.005       0.003
# SMB            0.0043      0.003      1.254      0.214      -0.003       0.011
# HML            0.0019      0.003      0.672      0.503      -0.004       0.007
# ==============================================================================
# Omnibus:                       17.241   Durbin-Watson:                   0.164
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.481
# Skew:                          -1.228   Prob(JB):                     2.17e-05
# Kurtosis:                       3.190   Cond. No.                         5.08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
rf = regress_data['RF'].mean()
market_premium = regress_data['mkt_excess'].mean()
size_premium = regress_data['SMB'].mean()
value_premium = regress_data['HML'].mean()

expected_monthly_return = rf + b1 * market_premium + b2 * size_premium + b3 * value_premium 
expected_yearly_return = expected_monthly_return * 10
print("Expected yearly return: " + str(expected_yearly_return))
# Out:
# Expected yearly return: 0.44512904202396586

# %%
plt.plot(ret_data)

# %% [markdown]
# ## 변수로 만들어보기...

# %%
def get_fama_french():
    datasets = ff.get_available_datasets( )
    df_3_factor = datasets[0]
    ds_factors = web.DataReader(df_3_factor,'famafrench', start='2008-01-01', end='2020-12-31')
    ds_factors[0].index = ds_factors[0].index.strftime('%Y-%m-%d')
    ds_3_factors = ds_factors[0]
    return ds_factors

# %%
ff_data = get_fama_french()
print(ff_data)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-549-ede3a648c51a> in <module>
# ----> 1 ff_data = get_fama_french()
#       2 print(ff_data)
#
# <ipython-input-548-7a28a85bc702> in get_fama_french()
#      23     # We will skip these rows
#      24
# ---> 25     ff_row = ff_factors.isnull().any(1).nonzero()[0][0]
#      26
#      27     # Read the csv file again with skipped rows
#
# UnboundLocalError: local variable 'ff_factors' referenced before assignment

# %%
# Last day of FF data
ff_last = ff_data.index[ff_data.shape[0] - 1].date()
# Build the get_price function
# We need 3 arguments, ticker, start and end date
def get_price_data(ticker, start, end):
    price = web.get_data_yahoo(ticker, start, end)
    price = price['Adj Close'] # keep only the Adj Price col
    return price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-546-8c82140da36e> in <module>
#       1 # Last day of FF data
# ----> 2 ff_last = ff_data.index[ff_data.shape[0] - 1].date()
#       3 # Build the get_price function
#       4 # We need 3 arguments, ticker, start and end date
#       5 def get_price_data(ticker, start, end):
#
# AttributeError: 'dict' object has no attribute 'index'

# %%
def run_reg_model(ticker,start,end):
    # Get FF data
    ff_data = get_fama_french()
    ff_last = ff_data.index[ff_data.shape[0] - 1].date()
    #Get the fund price data
    price_data = get_price_data(ticker,start,end)
    price_data = price_data.loc[:ff_last]
    ret_data = get_return_data(price_data, "M")
    all_data = pd.merge(pd.DataFrame(ret_data),ff_data, how = 'inner', left_index= True, right_index= True)
    all_data.rename(columns={"Mkt-RF":"mkt_excess"}, inplace=True)
    all_data['port_excess'] = all_data['portfolio'] - all_data['RF']
    # Run the model
    model = smf.formula.ols(formula = "port_excess ~ mkt_excess + SMB + HML", data = all_data).fit()
    return model.params

# %%
ggrax_model = run_reg_model("GGRAX", start = "2008-01-01", end = "2021-10-21")
print(ggrax_model)
