# %%
import pandas as pd
import pandas_datareader as pdr
import FinanceDataReader as fdr

# %% [markdown]
# Dubai / 동 / 선박운임료 / 석탄의 경우 Bloomberg Terminal 활용하여 확보
# 코로나 관련 데이터는 깃허브의 csv파일로 확보
# S&P Energy 가격은 Investing.com을 통해 csv파일로 확보하였다.
# 그 외의 데이터는 Pandas_datareader 와 FinanceDataReader를 통해 확보하였다.

# %%
### WTI유 가격 불러오기

df_WTI = pdr.DataReader('DCOILWTICO', 'fred', start='2000-01-01')

print('row count:', len(df_WTI))
df_WTI.tail(10)
# Out:
# row count: 5686
#             DCOILWTICO
# DATE
# 2021-10-05       79.17
# 2021-10-06       77.66
# 2021-10-07       78.46
# 2021-10-08       79.55
# 2021-10-11       80.64
# 2021-10-12       80.75
# 2021-10-13       80.67
# 2021-10-14       81.43
# 2021-10-15       82.39
# 2021-10-18       82.62

# %%
### Brent유 가격 불러오기

df_Brent = pdr.DataReader('DCOILBRENTEU', 'fred', start='2001-01-01')

print('row count:', len(df_Brent))
df_Brent.head(10)
# Out:
# row count: 5426
#             DCOILBRENTEU
# DATE
# 2001-01-01           NaN
# 2001-01-02         23.43
# 2001-01-03         23.44
# 2001-01-04         24.57
# 2001-01-05         24.77
# 2001-01-08         24.75
# 2001-01-09         24.13
# 2001-01-10         24.98
# 2001-01-11         25.60
# 2001-01-12         25.63

# %%
### Dubai유 가격 불러오기

df_Dubai = pd.read_excel("data/dubai_weekly.xlsx")

print('row count:', len(df_Dubai))
df_Dubai.Date = pd.to_datetime(df_Dubai.Date)
df_Dubai.set_index(df_Dubai.Date,drop = True, inplace = True)
df_Dubai.drop(['Date'],axis = 1, inplace = True)
df_Dubai
# Out:
# row count: 145
#             Price
# Date
# 2021-09-30  72.53
# 2021-09-03  71.46
# 2021-07-09  66.10
# 2021-07-02  62.95
# 2021-06-04  64.28
# ...           ...
# 2010-01-08  77.49
# 2010-01-01  72.95
# 2009-12-04  68.04
# 2009-10-09  71.39
# 2009-10-02  65.02
#
# [145 rows x 1 columns]

# %%
### 천연가스 가격 불러오기

df_gas = pd.read_excel("data/natural_gas_daily.xlsx")

print('row count:', len(df_gas))
df_gas.Date = pd.to_datetime(df_gas.Date)
df_gas.set_index(df_gas.Date, drop = True, inplace = True)
df_gas.drop(['Date'],axis = 1, inplace = True)
df_gas
# Out:
# row count: 3851
#             Price
# Date
# 2021-10-20  5.170
# 2021-10-19  5.088
# 2021-10-18  4.989
# 2021-10-15  5.410
# 2021-10-14  5.687
# ...           ...
# 2006-07-28  7.184
# 2006-07-27  7.042
# 2006-07-26  6.887
# 2006-07-25  6.409
# 2006-07-24  6.605
#
# [3851 rows x 1 columns]

# %%
### 금가격 불러오기

df_gold = pdr.DataReader('GOLDAMGBD228NLBM', 'fred', start='2000-01-01')

print('row count:', len(df_gold))
df_gold.tail(10)
# Out:
# row count: 5692
#             GOLDAMGBD228NLBM
# DATE
# 2021-10-13           1767.45
# 2021-10-14           1797.15
# 2021-10-15           1781.45
# 2021-10-18           1762.45
# 2021-10-19           1779.40
# 2021-10-20           1778.15
# 2021-10-21           1785.30
# 2021-10-22           1792.30
# 2021-10-25           1799.20
# 2021-10-26           1801.90

# %%
### 은가격 불러오기

df_silver = pdr.DataReader('SLVPRUSD', 'fred', start='2008-01-01')

print('row count:', len(df_silver))
df_silver
# Out:
# row count: 1062
#             SLVPRUSD
# DATE
# 2017-10-02    16.580
# 2017-10-03    16.610
# 2017-10-04    16.825
# 2017-10-05    16.660
# 2017-10-06    16.625
# ...              ...
# 2021-10-20    23.955
# 2021-10-21    24.230
# 2021-10-22    24.310
# 2021-10-25    24.375
# 2021-10-26    24.315
#
# [1062 rows x 1 columns]

# %%
### 동가격 불러오기

df_copper = pd.read_excel('data/copper_daily.xlsx')

print('row count:', len(df_copper))
df_copper.Date = pd.to_datetime(df_copper.Date)
df_copper.set_index(df_copper.Date,drop = True, inplace = True)
df_copper.drop(['Date'],axis = 1, inplace = True)
df_copper
# Out:
# row count: 3528
#               Price
# Date
# 2021-10-20  10185.5
# 2021-10-19  10149.5
# 2021-10-18  10196.0
# 2021-10-15  10281.0
# 2021-10-14   9984.0
# ...             ...
# 2008-02-07   7540.0
# 2008-02-06   7330.0
# 2008-02-05   7130.0
# 2008-02-04   7260.0
# 2008-02-01   7230.0
#
# [3528 rows x 1 columns]

# %%
#코로나 데이터
import pandas as pd
import numpy as np
df_covid19= pd.read_csv('data/owid-covid-data.csv')

print('row count:', len(df_covid19))
df_covid19
# Out:
# row count: 125732
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 125727      ZWE    Africa     Zimbabwe  2021-10-19     132405.0       37.0
# 125728      ZWE    Africa     Zimbabwe  2021-10-20     132437.0       32.0
# 125729      ZWE    Africa     Zimbabwe  2021-10-21     132540.0      103.0
# 125730      ZWE    Africa     Zimbabwe  2021-10-22     132588.0       48.0
# 125731      ZWE    Africa     Zimbabwe  2021-10-23     132588.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 125727              55.571        4659.0         1.0                2.000
# 125728              47.000        4659.0         0.0                1.571
# 125729              41.286        4662.0         3.0                1.000
# 125730              43.286        4663.0         1.0                1.143
# 125731              36.429        4663.0         0.0                0.857
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 125727  ...             1.6          30.7                  36.791
# 125728  ...             1.6          30.7                  36.791
# 125729  ...             1.6          30.7                  36.791
# 125730  ...             1.6          30.7                  36.791
# 125731  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 125727                         1.7            61.49                    0.571
# 125728                         1.7            61.49                    0.571
# 125729                         1.7            61.49                    0.571
# 125730                         1.7            61.49                    0.571
# 125731                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 125727                                   NaN                          NaN
# 125728                                   NaN                          NaN
# 125729                                   NaN                          NaN
# 125730                                   NaN                          NaN
# 125731                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 125727               NaN                                      NaN
# 125728               NaN                                      NaN
# 125729               NaN                                      NaN
# 125730               NaN                                      NaN
# 125731               NaN                                      NaN
#
# [125732 rows x 65 columns]

# %% [markdown]
# Variable	:  Description
#
# *   total_cases	: Total confirmed cases of COVID-19
# * total_vaccinations : Total number of COVID-19 vaccination doses administered (투여된 수)
# *   people_fully_vaccinated: Total number of people who received all doses prescribed by the vaccination protocol (예방 접종 프로토콜에 명시된 모든 용량을 접종받은 총 사람 수)

# %%
df_tcvx= df_covid19[['continent','location', 'date', 'total_cases', 'new_vaccinations', 'people_fully_vaccinated', 'new_cases']]
df_tcvx = df_tcvx.fillna(0)
df_tcvx.tail()
# Out:
#        continent  location        date  total_cases  new_vaccinations  \
# 125727    Africa  Zimbabwe  2021-10-19     132405.0           13759.0
# 125728    Africa  Zimbabwe  2021-10-20     132437.0           24020.0
# 125729    Africa  Zimbabwe  2021-10-21     132540.0           16516.0
# 125730    Africa  Zimbabwe  2021-10-22     132588.0               0.0
# 125731    Africa  Zimbabwe  2021-10-23     132588.0               0.0
#
#         people_fully_vaccinated  new_cases
# 125727                2509195.0       37.0
# 125728                2523407.0       32.0
# 125729                2532854.0      103.0
# 125730                      0.0       48.0
# 125731                      0.0        0.0

# %%
### 코로나 백신 접종자수 불러오기
c_data = df_tcvx.groupby(['date']).sum()
corona_data = c_data[['new_cases','new_vaccinations']]
corona_data.index = pd.to_datetime(corona_data.index)
corona_data
# Out:
#             new_cases  new_vaccinations
# date
# 2020-01-01        0.0               0.0
# 2020-01-02        0.0               0.0
# 2020-01-03        0.0               0.0
# 2020-01-04        0.0               0.0
# 2020-01-05        0.0               0.0
# ...               ...               ...
# 2021-10-19  1419351.0        79280514.0
# 2021-10-20  1506523.0        87751863.0
# 2021-10-21  1473414.0        65003904.0
# 2021-10-22  1569272.0        51138783.0
# 2021-10-23  1139204.0               0.0
#
# [662 rows x 2 columns]

# %% [markdown]
# 코로나 데이터의 경우 NA값은 관측되지 않은 것이라고 판단, 자체적으로 0값으로 치환하였다.

# %%
### 선박운임료 불러오기

df_bdiy = pd.read_excel('data/bdiy_daily_data.xlsx')
print('row count:', len(df_bdiy))
df_bdiy.Date = pd.to_datetime(df_bdiy.Date)
df_bdiy.set_index(df_bdiy.Date,drop = True, inplace = True)
df_bdiy.drop(['Date'],axis = 1, inplace = True)
df_bdiy
# Out:
# row count: 3451
#             Price
# Date
# 2021-10-20   4751
# 2021-10-19   4714
# 2021-10-18   4732
# 2021-10-15   4854
# 2021-10-14   5062
# ...           ...
# 2008-01-08   8730
# 2008-01-07   8732
# 2008-01-04   8702
# 2008-01-03   8756
# 2008-01-02   8891
#
# [3451 rows x 1 columns]

# %%
### 석탄가격 불러오기
df_coal = pd.read_excel('data/coal_index_daily.xlsx')

print('row count:', len(df_coal))
df_coal.Date = pd.to_datetime(df_coal.Date)
df_coal.set_index(df_coal.Date,drop = True, inplace = True)
df_coal.drop(['Date'],axis = 1, inplace = True)
df_coal
# Out:
# row count: 3390
#               Price
# Date
# 2020-12-18  1195.81
# 2020-12-17  1179.04
# 2020-12-16  1177.70
# 2020-12-15  1159.74
# 2020-12-14  1164.29
# ...             ...
# 2007-12-18  5240.59
# 2007-12-17  5216.20
# 2007-12-14  5371.14
# 2007-12-13  5450.96
# 2007-12-12  5514.90
#
# [3390 rows x 1 columns]

# %%
### 비트코인 불러오기

df = fdr.DataReader('BTC/USD', '2015-01-01', '2021-10-21')
df_bit = df['Close']
df_bit
# Out:
# Date
# 2015-01-01      314.9
# 2015-01-02      315.2
# 2015-01-03      287.1
# 2015-01-04      264.7
# 2015-01-05      274.8
#                ...
# 2021-10-17    61527.5
# 2021-10-18    62056.3
# 2021-10-19    64278.5
# 2021-10-20    65979.1
# 2021-10-21    62210.2
# Name: Close, Length: 2486, dtype: float64

# %%
### 달러인덱스 불러오기

df = fdr.DataReader('DX', '2008-01-01', '2021-10-21')
df_dollar = df['Close']
df_dollar
# Out:
# Date
# 2008-01-02    76.010
# 2008-01-03    75.920
# 2008-01-04    75.820
# 2008-01-07    76.200
# 2008-01-08    76.120
#                ...
# 2021-10-15    93.938
# 2021-10-18    93.945
# 2021-10-19    93.728
# 2021-10-20    93.535
# 2021-10-21    93.758
# Name: Close, Length: 3560, dtype: float64

# %%
### S&P지수 불러오기

df = fdr.DataReader('US500', '2008-01-01', '2021-10-21')
df_Snp = df['Close']
df_Snp
# Out:
# Date
# 2008-01-02    1447.16
# 2008-01-03    1447.16
# 2008-01-04    1411.63
# 2008-01-07    1416.18
# 2008-01-08    1390.19
#                ...
# 2021-10-15    4471.37
# 2021-10-18    4486.48
# 2021-10-19    4519.63
# 2021-10-20    4536.19
# 2021-10-21    4549.78
# Name: Close, Length: 3477, dtype: float64

# %%
### S&P Energy index 불러오기

df = pd.read_csv('data/S&PEnergy.csv')
df.Date = pd.to_datetime(df.Date)
df.set_index(df.Date,drop = True, inplace = True)
df.drop(['Date'],axis = 1, inplace = True)
# for idx, val in enumerate(df['Vol.']):
#     new = val[0:-1]
#     print(idx, new)
#     float(new)
df_energy = df[['Open','High','Low','Vol.','Price']]
df_energy
# Out:
#               Open    High     Low     Vol.   Price
# Date
# 2021-10-25  439.56  448.63  439.56  177.93M  445.91
# 2021-10-22  435.50  440.04  433.27  160.55M  439.56
# 2021-10-21  443.53  443.53  432.10  204.82M  435.50
# 2021-10-20  439.87  443.62  435.16  173.73M  443.53
# 2021-10-19  434.89  441.40  434.47  175.70M  439.87
# ...            ...     ...     ...      ...     ...
# 2007-10-03  579.86  579.86  570.66  151.00M  574.23
# 2007-10-02  587.30  587.30  573.45  164.89M  579.86
# 2007-10-01  579.47  587.65  578.33  156.07M  587.30
# 2007-09-28  582.05  587.63  576.68  147.43M  579.47
# 2007-09-27  576.89  583.47  576.89  146.26M  582.05
#
# [3549 rows x 5 columns]

# %% [markdown]
# # 데이터 합치기 및 확인(+EDA)

# %%
# 데이터 합본
data_list = (df_WTI, df_Brent,df_Dubai,df_gas,df_gold,df_silver,df_copper,df_bdiy,df_coal,corona_data,df_dollar,df_Snp,df_energy)
df_raw = pd.DataFrame()
for i in data_list:
    df_raw = pd.concat([df_raw, i], axis = 1)

df_raw.columns = ['WTI','Brent','Dubai','Gas','Gold','Silver','Copper','Bdiy','Coal','new_cases','vaccination','Bitcoin','Snp','Open','High','Low','Volume','Energy']
df_raw
# Out:
#               WTI  Brent  Dubai  Gas     Gold  Silver  Copper  Bdiy  Coal  \
# 2000-01-03    NaN    NaN    NaN  NaN      NaN     NaN     NaN   NaN   NaN
# 2000-01-04  25.56    NaN    NaN  NaN   282.05     NaN     NaN   NaN   NaN
# 2000-01-05  24.65    NaN    NaN  NaN   282.10     NaN     NaN   NaN   NaN
# 2000-01-06  24.79    NaN    NaN  NaN   280.35     NaN     NaN   NaN   NaN
# 2000-01-07  24.79    NaN    NaN  NaN   282.00     NaN     NaN   NaN   NaN
# ...           ...    ...    ...  ...      ...     ...     ...   ...   ...
# 2021-10-21    NaN    NaN    NaN  NaN  1785.30  24.230     NaN   NaN   NaN
# 2021-10-22    NaN    NaN    NaN  NaN  1792.30  24.310     NaN   NaN   NaN
# 2021-10-23    NaN    NaN    NaN  NaN      NaN     NaN     NaN   NaN   NaN
# 2021-10-25    NaN    NaN    NaN  NaN  1799.20  24.375     NaN   NaN   NaN
# 2021-10-26    NaN    NaN    NaN  NaN  1801.90  24.315     NaN   NaN   NaN
#
#             new_cases  vaccination  Bitcoin      Snp    Open    High     Low  \
# 2000-01-03        NaN          NaN      NaN      NaN     NaN     NaN     NaN
# 2000-01-04        NaN          NaN      NaN      NaN     NaN     NaN     NaN
# 2000-01-05        NaN          NaN      NaN      NaN     NaN     NaN     NaN
# 2000-01-06        NaN          NaN      NaN      NaN     NaN     NaN     NaN
# 2000-01-07        NaN          NaN      NaN      NaN     NaN     NaN     NaN
# ...               ...          ...      ...      ...     ...     ...     ...
# 2021-10-21  1473414.0   65003904.0   93.758  4549.78  443.53  443.53  432.10
# 2021-10-22  1569272.0   51138783.0      NaN      NaN  435.50  440.04  433.27
# 2021-10-23  1139204.0          0.0      NaN      NaN     NaN     NaN     NaN
# 2021-10-25        NaN          NaN      NaN      NaN  439.56  448.63  439.56
# 2021-10-26        NaN          NaN      NaN      NaN     NaN     NaN     NaN
#
#              Volume  Energy
# 2000-01-03      NaN     NaN
# 2000-01-04      NaN     NaN
# 2000-01-05      NaN     NaN
# 2000-01-06      NaN     NaN
# 2000-01-07      NaN     NaN
# ...             ...     ...
# 2021-10-21  204.82M  435.50
# 2021-10-22  160.55M  439.56
# 2021-10-23      NaN     NaN
# 2021-10-25  177.93M  445.91
# 2021-10-26      NaN     NaN
#
# [5881 rows x 18 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5881 entries, 2000-01-03 to 2021-10-26
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   WTI          5471 non-null   float64
#  1   Brent        5284 non-null   float64
#  2   Dubai        145 non-null    float64
#  3   Gas          3843 non-null   float64
#  4   Gold         5512 non-null   float64
#  5   Silver       1024 non-null   float64
#  6   Copper       3468 non-null   float64
#  7   Bdiy         3451 non-null   float64
#  8   Coal         3342 non-null   float64
#  9   new_cases    662 non-null    float64
#  10  vaccination  662 non-null    float64
#  11  Bitcoin      3560 non-null   float64
#  12  Snp          3477 non-null   float64
#  13  Open         3549 non-null   float64
#  14  High         3549 non-null   float64
#  15  Low          3549 non-null   float64
#  16  Volume       3549 non-null   object
#  17  Energy       3549 non-null   float64
# dtypes: float64(17), object(1)
# memory usage: 873.0+ KB

# %% [markdown]
# #### 은의 경우 1000여개 / 두바이의 경우 월 가격 데이터를 확보하였다. 따라서 이 두개의 데이터는 탈락시키고 활용할 계획이다
# (석탄은 2020년까지이므로 잠시 탈락)

# %%
df_raw.describe()
# Out:
#                WTI        Brent       Dubai          Gas         Gold  \
# count  5471.000000  5284.000000  145.000000  3843.000000  5512.000000
# mean     60.992248    65.140960   73.751172     4.011943  1005.519113
# std      25.737067    28.866938   25.246233     1.975923   503.871074
# min     -36.980000     9.120000   22.650000     1.482000   256.700000
# 25%      40.445000    43.495000   54.390000     2.734500   437.462500
# 50%      58.170000    61.875000   69.940000     3.467000  1161.000000
# 75%      79.630000    81.880000  102.230000     4.459500  1336.025000
# max     145.310000   143.950000  122.100000    13.577000  2061.500000
#
#             Silver        Copper          Bdiy         Coal     new_cases  \
# count  1024.000000   3468.000000   3451.000000  3342.000000  6.620000e+02
# mean     19.064473   6758.228590   1828.730223  2799.604324  1.160036e+06
# std       4.467211   1452.733206   1785.772142  1797.331883  7.756418e+05
# min      12.005000   2845.000000    290.000000   573.590000  0.000000e+00
# 25%      15.568750   5821.750000    868.500000  1486.387500  4.159292e+05
# 50%      17.077500   6739.500000   1262.000000  2079.615000  1.190258e+06
# 75%      23.843750   7680.000000   1960.000000  4326.652500  1.754110e+06
# max      29.585000  10460.000000  11793.000000  8019.460000  2.899671e+06
#
#         vaccination      Bitcoin          Snp         Open         High  \
# count  6.620000e+02  3560.000000  3477.000000  3549.000000  3549.000000
# mean   3.035822e+07    87.706397  2055.858361   491.983474   496.795238
# std    4.321973e+07     8.435555   879.318882   100.771609   100.230308
# min    0.000000e+00    71.304000   676.530000   179.940000   193.260000
# 25%    0.000000e+00    80.201000  1319.050000   426.790000   430.540000
# 50%    0.000000e+00    88.489000  1973.280000   501.470000   505.750000
# 75%    6.290904e+07    95.645750  2680.500000   560.730000   565.890000
# max    1.549071e+08   103.605000  4549.780000   736.840000   738.710000
#
#                Low       Energy
# count  3549.000000  3549.000000
# mean    486.862516   491.955638
# std     101.205875   100.759319
# min     172.450000   179.940000
# 25%     422.060000   426.790000
# 50%     496.650000   501.470000
# 75%     556.160000   560.660000
# max     734.510000   737.090000

# %%
#2008년 데이터 합본 ( 동 가격을 기준으로 2월 시작이다)
data_list = (df_WTI, df_Brent,df_gas,df_gold,df_copper,df_bdiy,df_dollar,df_Snp,df_energy)
df_2008 = pd.DataFrame()
for i in data_list:
    df_2008 = pd.concat([df_2008, i], axis = 1)

df_2008.columns = ['WTI','Brent','Gas','Gold','Copper','Bdiy','Dollar','Snp','Open','High','Low','Volume','Energy']
df_2008 = df_2008.dropna()
df_2008
# Out:
#               WTI  Brent    Gas     Gold   Copper    Bdiy  Dollar      Snp  \
# 2008-02-01  89.03  91.41  7.740   933.00   7230.0  6134.0  75.565  1395.42
# 2008-02-04  90.07  91.09  7.869   899.50   7260.0  6121.0  75.470  1380.82
# 2008-02-05  88.32  89.60  7.942   889.75   7130.0  6032.0  76.285  1336.64
# 2008-02-06  87.16  88.73  7.994   892.00   7330.0  6002.0  76.300  1326.45
# 2008-02-07  88.07  88.55  8.102   908.25   7540.0  6135.0  77.120  1336.91
# ...           ...    ...    ...      ...      ...     ...     ...      ...
# 2021-10-12  80.75  83.53  5.505  1759.10   9465.0  5378.0  94.519  4350.64
# 2021-10-13  80.67  83.53  5.590  1767.45   9651.0  5206.0  94.080  4363.80
# 2021-10-14  81.43  83.86  5.687  1797.15   9984.0  5062.0  93.961  4438.23
# 2021-10-15  82.39  84.67  5.410  1781.45  10281.0  4854.0  93.938  4471.37
# 2021-10-18  82.62  84.13  4.989  1762.45  10196.0  4732.0  93.945  4486.48
#
#               Open    High     Low   Volume  Energy
# 2008-02-01  537.15  544.62  534.29  238.36M  540.81
# 2008-02-04  540.81  544.41  535.15  188.02M  541.30
# 2008-02-05  541.29  541.29  521.00  243.54M  521.00
# 2008-02-06  520.99  527.14  511.26  243.06M  512.79
# 2008-02-07  512.10  523.59  507.85  234.50M  518.83
# ...            ...     ...     ...      ...     ...
# 2021-10-12  427.71  431.79  425.04  194.73M  427.60
# 2021-10-13  427.60  429.51  420.00  171.54M  427.19
# 2021-10-14  427.19  433.94  427.19  167.51M  432.43
# 2021-10-15  432.43  438.73  432.43  173.94M  434.44
# 2021-10-18  434.44  441.08  432.57  217.66M  434.89
#
# [3341 rows x 13 columns]

# %%
df_2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3341 entries, 2008-02-01 to 2021-10-18
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   WTI     3341 non-null   float64
#  1   Brent   3341 non-null   float64
#  2   Gas     3341 non-null   float64
#  3   Gold    3341 non-null   float64
#  4   Copper  3341 non-null   float64
#  5   Bdiy    3341 non-null   float64
#  6   Dollar  3341 non-null   float64
#  7   Snp     3341 non-null   float64
#  8   Open    3341 non-null   float64
#  9   High    3341 non-null   float64
#  10  Low     3341 non-null   float64
#  11  Volume  3341 non-null   object
#  12  Energy  3341 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 365.4+ KB

# %%
#2020년 데이터 합본
data_list = (df_WTI, df_Brent,df_gas,df_gold,df_copper,df_bdiy,corona_data,df_dollar,df_bit,df_Snp,df_energy)
df_2020 = pd.DataFrame()
for i in data_list:
    df_2020 = pd.concat([df_2020, i], axis = 1)

df_2020.columns = ['WTI','Brent','Gas','Gold','Copper','Bdiy','new_cases','vaccination','Dollar','Bitcoin','Snp','Open','High','Low','Volume','Energy']
df_2020 = df_2020.dropna()
# for idx, val in enumerate(df_2020['Volume']):
#     new = val[0:-1]
#     float(new)

# %% [markdown]
# # 2008년 이후부터 계속 있는 데이터
# ## 기름 / 금속류 / bdiy / 석탄 / 달러 / SNP
#
#
# # 2020년 코로나 데이터를 포함하는 데이터
# ## + 코로나 / 비트코인

# %% [markdown]
# EDA 및 시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_hm=df_2008.drop(['Open','High', 'Low'],axis=1)
df_hm.head()
df_hm_corr = df_hm.corr()
df_hm_corr
# Out:
#              WTI     Brent       Gas      Gold    Copper      Bdiy    Dollar  \
# WTI     1.000000  0.971174  0.604178 -0.030203  0.657550  0.467486 -0.830693
# Brent   0.971174  1.000000  0.478358  0.101154  0.688099  0.335824 -0.801346
# Gas     0.604178  0.478358  1.000000 -0.467430  0.266829  0.839374 -0.605420
# Gold   -0.030203  0.101154 -0.467430  1.000000  0.496014 -0.304292  0.107558
# Copper  0.657550  0.688099  0.266829  0.496014  1.000000  0.335289 -0.536075
# Bdiy    0.467486  0.335824  0.839374 -0.304292  0.335289  1.000000 -0.458511
# Dollar -0.830693 -0.801346 -0.605420  0.107558 -0.536075 -0.458511  1.000000
# Snp    -0.442992 -0.420492 -0.394656  0.520592  0.089298 -0.149932  0.675210
# Energy  0.630266  0.639741  0.281322 -0.250321  0.223732  0.035117 -0.327474
#
#              Snp    Energy
# WTI    -0.442992  0.630266
# Brent  -0.420492  0.639741
# Gas    -0.394656  0.281322
# Gold    0.520592 -0.250321
# Copper  0.089298  0.223732
# Bdiy   -0.149932  0.035117
# Dollar  0.675210 -0.327474
# Snp     1.000000 -0.299806
# Energy -0.299806  1.000000

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df_hm_corr, annot=True)
plt.title('Stock correlation', fontsize=20)
plt.show()

# %%
X= df_hm.index
y1= df_hm.WTI
y2= df_hm.Brent
y3= df_hm.Gas
y4= df_hm.Gold
y5= df_hm.Copper
y6= df_hm.Bdiy
y7= df_hm.Dollar
y8= df_hm.Snp
#y9= df_hm.Volume
y10= df_hm.Energy

# %%
plt.figure(figsize=(20,7))
plt.plot(X, y1, label = 'WTI')
plt.plot(X, y2, label = 'Brent')
plt.plot(X, y3, label = 'Gas')
plt.plot(X, y4, label = 'Gold')
plt.plot(X, y5, label = 'Copper')
plt.plot(X, y6, label = 'Bdiy')
plt.plot(X, y7, label = 'Dollar')
plt.plot(X, y8, label = 'SNP')
# plt.plot(X, y9, label = 'Volume')
plt.plot(X, y10, label = 'Energy')

plt.legend(loc='upper left')
plt.title('Stock Price')
plt.xlabel('Date')
plt.ylabel('Price')

plt.show()

# %%
#변동수치로 데이터 셋 만들기
#df_2008['Energy'] = (df_raw.Energy - df_raw.Energy.shift(1)) / df_raw.Energy.shift(1) * 100
#df_2008.Energy

# %%
X = df_2008.iloc[:,0:11]  # volume 값의 경우 2019년 이후로 작성되지 않아 여기선 미반영 하겠다
Y = df_2008['Energy']

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(Y,X)

res = model.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 Energy   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          7.941e+06
# Date:                Wed, 27 Oct 2021   Prob (F-statistic):                        0.00
# Time:                        14:14:37   Log-Likelihood:                         -8510.5
# No. Observations:                3341   AIC:                                  1.704e+04
# Df Residuals:                    3330   BIC:                                  1.711e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# WTI            0.0237      0.013      1.756      0.079      -0.003       0.050
# Brent         -0.0216      0.013     -1.715      0.086      -0.046       0.003
# Gas           -0.0147      0.076     -0.193      0.847      -0.164       0.134
# Gold        1.707e-05      0.000      0.039      0.969      -0.001       0.001
# Copper         0.0001   7.51e-05      1.361      0.174   -4.51e-05       0.000
# Bdiy       -9.156e-05   7.17e-05     -1.278      0.201      -0.000    4.89e-05
# Dollar         0.0033      0.007      0.479      0.632      -0.010       0.017
# Snp           -0.0002      0.000     -2.421      0.016      -0.000   -4.76e-05
# Open          -0.5801      0.011    -50.570      0.000      -0.603      -0.558
# High           0.8020      0.013     64.018      0.000       0.777       0.827
# Low            0.7776      0.011     73.510      0.000       0.757       0.798
# ==============================================================================
# Omnibus:                      322.278   Durbin-Watson:                   2.273
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2357.215
# Skew:                           0.075   Prob(JB):                         0.00
# Kurtosis:                       7.112   Cond. No.                     1.09e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.09e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# LSTM

# %%
data = X

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(data)
train = scaler.transform(data)

# %%
def buildDataSet(timeSeries , seqLength):
    xdata= []
    ydata = []
    for i in range(0 , len(timeSeries)- seqLength):
        tx = timeSeries[i:i+seqLength, : -1]
        ty = timeSeries[i+seqLength, [-1]]
        xdata.append(tx)
        ydata.append(ty)
    
    return np.array(xdata),np.array(ydata)

x_train, y_train = buildDataSet(train, 13)

# %%
x_train.shape
# Out:
# (3328, 13, 2)

# %%
from tensorflow.keras.layers import SimpleRNN , LSTM , GRU , Dense
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(LSTM(16, 
               input_shape=(x_train.shape[1],x_train.shape[2]), 
               activation='tanh', 
               return_sequences=True)
          )
model.add(LSTM(16, activation = 'tanh'))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_39 (LSTM)               (None, 13, 16)            1216
# _________________________________________________________________
# lstm_40 (LSTM)               (None, 16)                2112
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 3,345
# Trainable params: 3,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse' , optimizer='adam' )

# %%
hist = model.fit(x_train , y_train ,epochs=100, batch_size = 1000)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 8s 88ms/step - loss: 0.2929
# Epoch 2/100
# 4/4 [==============================] - 1s 97ms/step - loss: 0.1801
# Epoch 3/100
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0895
# Epoch 4/100
# 4/4 [==============================] - 1s 83ms/step - loss: 0.0293
# Epoch 5/100
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0076
# Epoch 6/100
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0172
# Epoch 7/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0214
# Epoch 8/100
# 4/4 [==============================] - 1s 114ms/step - loss: 0.0126
# Epoch 9/100
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0068
# Epoch 10/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0070
# Epoch 11/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0081
# Epoch 12/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0076
# Epoch 13/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0061
# Epoch 14/100
# 4/4 [==============================] - 1s 119ms/step - loss: 0.0053
# Epoch 15/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0052
# Epoch 16/100
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0051
# Epoch 17/100
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0046
# Epoch 18/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0042
# Epoch 19/100
# 4/4 [==============================] - ETA: 0s - loss: 0.003 - 0s 73ms/step - loss: 0.0039
# Epoch 20/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0037
# Epoch 21/100
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0034
# Epoch 22/100
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0032
# Epoch 23/100
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0030
# Epoch 24/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0027
# Epoch 25/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0025
# Epoch 26/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0024
# Epoch 27/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0022: 0s - loss: 0.00
# Epoch 28/100
# 4/4 [==============================] - 0s 65ms/step - loss: 0.0021
# Epoch 29/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0019
# Epoch 30/100
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0018
# Epoch 31/100
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0017
# Epoch 32/100
# 4/4 [==============================] - 0s 65ms/step - loss: 0.0016
# Epoch 33/100
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0015
# Epoch 34/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0015
# Epoch 35/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0014
# Epoch 36/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0014
# Epoch 37/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0013
# Epoch 38/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0013
# Epoch 39/100
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0013
# Epoch 40/100
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0013
# Epoch 41/100
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0012
# Epoch 42/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0012
# Epoch 43/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0012
# Epoch 44/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0012
# Epoch 45/100
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0012
# Epoch 46/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0012
# Epoch 47/100
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0012
# Epoch 48/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0012
# Epoch 49/100
# 4/4 [==============================] - 0s 62ms/step - loss: 0.0012
# Epoch 50/100
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0012
# Epoch 51/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0012
# Epoch 52/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0012
# Epoch 53/100
# 4/4 [==============================] - 0s 62ms/step - loss: 0.0012
# Epoch 54/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0012
# Epoch 55/100
# 4/4 [==============================] - 0s 65ms/step - loss: 0.0012
# Epoch 56/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0012
# Epoch 57/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0012
# Epoch 58/100
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0012
# Epoch 59/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0012
# Epoch 60/100
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0012
# Epoch 61/100
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0012
# Epoch 62/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0012
# Epoch 63/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0012
# Epoch 64/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0012
# Epoch 65/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0012
# Epoch 66/100
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0012
# Epoch 67/100
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0012
# Epoch 68/100
# 4/4 [==============================] - 0s 65ms/step - loss: 0.0012
# Epoch 69/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0012
# Epoch 70/100
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0012
# Epoch 71/100
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0012
# Epoch 72/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0012
# Epoch 73/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0012
# Epoch 74/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0012
# Epoch 75/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0012
# Epoch 76/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0012
# Epoch 77/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0012
# Epoch 78/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0012
# Epoch 79/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0012
# Epoch 80/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0012
# Epoch 81/100
# 4/4 [==============================] - 0s 92ms/step - loss: 0.0012
# Epoch 82/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0012
# Epoch 83/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0012
# Epoch 84/100
# 4/4 [==============================] - 0s 62ms/step - loss: 0.0012
# Epoch 85/100
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0012
# Epoch 86/100
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0012
# Epoch 87/100
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0012
# Epoch 88/100
# 4/4 [==============================] - 0s 62ms/step - loss: 0.0012
# Epoch 89/100
# 4/4 [==============================] - 0s 62ms/step - loss: 0.0012
# Epoch 90/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0012
# Epoch 91/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0012
# Epoch 92/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0012
# Epoch 93/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0012
# Epoch 94/100
# 4/4 [==============================] - 0s 59ms/step - loss: 0.0012
# Epoch 95/100
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0012
# Epoch 96/100
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0012
# Epoch 97/100
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0012
# Epoch 98/100
# 4/4 [==============================] - 0s 62ms/step - loss: 0.0012
# Epoch 99/100
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0012
# Epoch 100/100
# 4/4 [==============================] - 0s 94ms/step - loss: 0.0012
